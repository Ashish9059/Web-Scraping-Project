# %% [markdown]
# #### Q.) What is Selenium and how do web drivers work?
# ##### Selenium is an open-source framework designed for testing. The Selenium Web Driver is just one part of the overall Selenium library. Selenium allows us to run our scripts in an automated process on the web driver, which helps us to decrease the time to scrape data. As it uses automation, we don’t have to manually do anything. Selenium supports a lot of web drivers, e.g., Chrome, Mozilla, Safari, etc.
#
# ##### Selenium Web Drivers basically work in 3 steps:
# - ##### First, the JSON wire protocol converts the test commands into an HTTP request.
# - ##### The Browser Driver, which is already present in each browser, is initialised before any script is executed.
# ##### Once everything is ready, the driver starts to send requests to the browser.
# - ##### Each Web Driver can directly call its browser. Whenever a script is executed, an HTTP request is generated by the JSON wire protocol. The browser driver uses an HTTP server for getting HTTP requests. After receiving and executing the request, the status is sent back to the HTTP server, which forwards it back to the script.

# %% [markdown]
# - WebDriver is a tool that lets you control a web browser from your code. It's like a remote control for your browser, allowing you to automate  tasks, test websites, and scrape data. Think of it as the bridge between your program and the web.

# %% [markdown]
# # Youtube Web Scraping | Understanding the Tags

# %%
from bs4 import BeautifulSoup
from selenium import webdriver
import pandas as pd
from tqdm import tqdm
import numpy as np
import time

# %%
browser = webdriver.Chrome()
browser.get('https://www.youtube.com/c/GeeksforGeeksVideos/videos')

# %%
soup = BeautifulSoup(browser.page_source,'html.parser')

# %% [markdown]
# # Youtube Web Scraping | Data from Channel Page

# %%
data = []
for sp in soup.find_all('ytd-rich-item-renderer'):

    try:
        title      = sp.find('a', class_ ='yt-simple-endpoint focus-on-expand style-scope ytd-rich-grid-media').text
    except:
        title = np.nan
    try:
        video_link = sp.find('a', class_ ='yt-simple-endpoint focus-on-expand style-scope ytd-rich-grid-media').get('href')
    except:
        video_link = np.nan
    try:
        views = sp.find_all('span' , class_ = 'inline-metadata-item style-scope ytd-video-meta-block')[0].text
    except:
        views = np.nan
    try:
        date_time  = sp.find_all('span' , class_ = 'inline-metadata-item style-scope ytd-video-meta-block')[1].text
    except:
        date_time = np.nan
    try:
        thumbnail_link = sp.find('img').get('src').split('?')[0]
    except:
        thumbnails_link = np.nan

    data.append([title,views,date_time,video_link,thumbnail_link])

# %%
data
# Out:
# [['Three 90 Challenge | 1.5 Cr Refunded | GeeksforGeeks',
#   '728 views',
#   '1 day ago',
#   '/watch?v=28wXxweOOFM',
#   'https://i.ytimg.com/vi/28wXxweOOFM/hqdefault.jpg'],
#  ['From Tier 3 College to 20LPA Package 🤑 at Harman as a Senior Software Engineer | My Journey',
#   '2.2K views',
#   '3 days ago',
#   '/watch?v=cGPpUdaISGE',
#   'https://i.ytimg.com/vi/cGPpUdaISGE/hqdefault.jpg'],
#  ['How I Built an AirBnb Clone from Scratch | MERN Stack Project | GeeksforGeeks',
#   '1.1K views',
#   '4 days ago',
#   '/watch?v=koTBLYNq63I',
#   'https://i.ytimg.com/vi/koTBLYNq63I/hqdefault.jpg'],
#  ['Master Web3 in 2024 (The Ultimate Roadmap) | Block Chain, Crypto Currency |',
#   '1.2K views',
#   '7 days ago',
#   '/watch?v=CKrM5ouILBg',
#   'https://i.ytimg.com/vi/CKrM5ouILBg/hqdefault.jpg'],
#  ['🚀 Do This to Learn DSA and Get a Job | *Free Resources Inside* | The Ultimate DSA Roadmap 📚',
#   '3.1K views',
#   '11 days ago',
#   '/watch?v=VdLUuIeuXqM',
#   'https://i.ytimg.com/vi/VdLUuIeuXqM/hqdefault.jpg'],
#  ['Learn Sorting in just 7 Hours with @SandeepJainGfG  | GeeksforGeeks',
#   '7.8K views',
#   '12 days ago',
#   '/watch?v=IsBMyMch0gw',
#   'https://i.ytimg.com/vi/IsBMyMch0gw/hqdefault.jpg'],
#  ['IIT Grads reveal TOP PLACEMENT SECRETS 🤯 | Advice, Get Job in 2024, Salary, Roadmap, Life at IIT',
#   '9.4K views',
#   '2 weeks ago',
#   '/watch?v=HqqF_4yORKU',
#   'https://i.ytimg.com/vi/HqqF_4yORKU/hqdefault.jpg'],
#  ['I Went to the House of a Recent IIT BOMBAY Grad & AI Researcher at Sprinklr | House Invasion Ep-1🚀',
#   '12K views',
#   '2 weeks ago',
#   '/watch?v=xvBlkjtmvBc',
#   'https://i.ytimg.com/vi/xvBlkjtmvBc/hqdefault.jpg'],
#  ['Time and Space Complexity explained in literally 5 minutes | Big O | Concepts made simple ep -1',
#   '1.2K views',
#   '2 weeks ago',
#   '/watch?v=jOMxKsUd6e0',
#   'https://i.ytimg.com/vi/jOMxKsUd6e0/hqdefault.jpg'],
#  ['JAVA Backend Live Classes | Master OOPs, Spring Boot & Practice with Projects | GeeksforGeeks',
#   '217K views',
#   '2 weeks ago',
#   '/watch?v=y5sN2D4Zkmo',
#   'https://i.ytimg.com/vi/y5sN2D4Zkmo/hqdefault.jpg'],
#  ['How to participate and win any Hackathon - A Complete Guide | What are Hackathons? | Top 5 Hackathon',
#   '2.9K views',
#   '3 weeks ago',
#   '/watch?v=_yNtUwnvHio',
#   'https://i.ytimg.com/vi/_yNtUwnvHio/hqdefault.jpg'],
#  ['Do this to get a 15+ LPA job right after BCA!! | BCA VS BTECH | Is BCA worth it in 2024?',
#   '1.9K views',
#   '3 weeks ago',
#   '/watch?v=w95555WsTMI',
#   'https://i.ytimg.com/vi/w95555WsTMI/hqdefault.jpg'],
#  ['Happening this Month at GeeksforGeeks Noida Center! | GfG Offline Classes',
#   '557 views',
#   '3 weeks ago',
#   '/watch?v=ZTvTaINuLGk',
#   'https://i.ytimg.com/vi/ZTvTaINuLGk/hqdefault.jpg'],
#  ['GeeksforGeeks Full Stack LIVE Classes | With Projects | Learn Full Stack Development in 14 Weeks',
#   '46K views',
#   '3 weeks ago',
#   '/watch?v=G5lsLsK9evc',
#   'https://i.ytimg.com/vi/G5lsLsK9evc/hqdefault.jpg'],
#  ['Do this to crack Placements in just 30 days | *Free Resources*',
#   '20K views',
#   '3 weeks ago',
#   '/watch?v=zicelfDj-i8',
#   'https://i.ytimg.com/vi/zicelfDj-i8/hqdefault.jpg'],
#  ['💸 How to become a Graphic Designer in 2024? | Complete Graphic Designer Roadmap',
#   '811 views',
#   '3 weeks ago',
#   '/watch?v=GF2CQAP4Va0',
#   'https://i.ytimg.com/vi/GF2CQAP4Va0/hqdefault.jpg'],
#  ['DYNAMIC PROGRAMMING PRACTICE PROBLEM | DSA Course | GeeksforGeeks',
#   '1.1K views',
#   '1 month ago',
#   '/watch?v=5Bfjt3oY564',
#   'https://i.ytimg.com/vi/5Bfjt3oY564/hqdefault.jpg'],
#  ['Can these College students win 6000rs by answering easy coding questions?| GeeksforGeeks\xa0Premium',
#   '1.6K views',
#   '1 month ago',
#   '/watch?v=JtLJyMeHxLk',
#   'https://i.ytimg.com/vi/JtLJyMeHxLk/hqdefault.jpg'],
#  ['Create a 3D AI Website using Three.js | Frontend Projects | GeeksforGeeks',
#   '2K views',
#   '1 month ago',
#   '/watch?v=rq67tD6OYXc',
#   'https://i.ytimg.com/vi/rq67tD6OYXc/hqdefault.jpg'],
#  ['React Native VS Flutter | I analysed the app development market for both',
#   '1.6K views',
#   '1 month ago',
#   '/watch?v=2keMefdv9s4',
#   'https://i.ytimg.com/vi/2keMefdv9s4/hqdefault.jpg'],
#  ['Quick Sort: Auxiliary Space Explained in 8 Minutes! | Lecture - 25 | GeeksforGeeks',
#   '626 views',
#   '1 month ago',
#   '/watch?v=47dzZ_58vIw',
#   'https://i.ytimg.com/vi/47dzZ_58vIw/hqdefault.jpg'],
#  ['Learn QUICK SORT ANALYSIS in 10 MINUTES | Lecture - 24 | GeeksforGeeks',
#   '584 views',
#   '1 month ago',
#   '/watch?v=8VYD2q8dDFU',
#   'https://i.ytimg.com/vi/8VYD2q8dDFU/hqdefault.jpg'],
#  ['Top Interview Tips for Fresh Graduates in 2024 | GeeksforGeeks',
#   '3.1K views',
#   '1 month ago',
#   '/watch?v=aoBD3t-bFLo',
#   'https://i.ytimg.com/vi/aoBD3t-bFLo/hqdefault.jpg'],
#  ['GeeksforGeeks Classroom Program | Noida | Pune | Bengaluru',
#   '949 views',
#   '1 month ago',
#   '/watch?v=zPHy8Ruso5k',
#   'https://i.ytimg.com/vi/zPHy8Ruso5k/hqdefault.jpg'],
#  ['Is Engineering (B.Tech) Worth it in 2024? | Harsh Reality',
#   '1.2K views',
#   '1 month ago',
#   '/watch?v=Qt1xh3R_1_Y',
#   'https://i.ytimg.com/vi/Qt1xh3R_1_Y/hqdefault.jpg'],
#  ['Hoare Partition Quick Sort - PART II | Sorting Playlist | Lecture - 23 | GeeksforGeeks',
#   '382 views',
#   '1 month ago',
#   '/watch?v=pNDNomHBDZk',
#   'https://i.ytimg.com/vi/pNDNomHBDZk/hqdefault.jpg'],
#  ['Why you will never become a Programmer? | Placements | Honest reality | GfG',
#   '4.1K views',
#   '1 month ago',
#   '/watch?v=pM1sSCio0WE',
#   'https://i.ytimg.com/vi/pM1sSCio0WE/hqdefault.jpg'],
#  ['Learn Lomuto Partition in Quick Sort | Lecture - 22 | GeeksforGeeks',
#   '501 views',
#   '1 month ago',
#   '/watch?v=R-LMKBKPTok',
#   'https://i.ytimg.com/vi/R-LMKBKPTok/hqdefault.jpg'],
#  ['How I would learn Data Engineering in 2024 (If I could start over) | Complete Roadmap |',
#   '1.2K views',
#   '1 month ago',
#   '/watch?v=XTbyBW8Yh9U',
#   'https://i.ytimg.com/vi/XTbyBW8Yh9U/hqdefault.jpg'],
#  ['Introduction to Quick Sort | Sorting Playlist | Lecture - 21 | GeeksforGeeks',
#   '931 views',
#   '1 month ago',
#   '/watch?v=SN8jC7Nb-Os',
#   'https://i.ytimg.com/vi/SN8jC7Nb-Os/hqdefault.jpg'],
#  ['GeeksforGeeks brings back Three 90 Challenge!',
#   '2.2M views',
#   '1 month ago',
#   '/watch?v=jTawc2mrQSw',
#   'https://i.ytimg.com/vi/jTawc2mrQSw/hqdefault.jpg'],
#  ["Big Companies vs Startups | Which one should you choose in 2024? | Startups | MNC'S",
#   '857 views',
#   '1 month ago',
#   '/watch?v=gkCKp0BgAy4',
#   'https://i.ytimg.com/vi/gkCKp0BgAy4/hqdefault.jpg'],
#  ['Hoare Partition Quick Sort | Lecture - 20 | GeeksforGeeks',
#   '859 views',
#   '1 month ago',
#   '/watch?v=NsY5UI0RZfE',
#   'https://i.ytimg.com/vi/NsY5UI0RZfE/hqdefault.jpg'],
#  ['GATE vs Placements🧑\u200d💻| Which one to choose after\xa0graduation? 🤔 | GATE | Engineering | GFG',
#   '835 views',
#   '1 month ago',
#   '/watch?v=N42PuoXkjgA',
#   'https://i.ytimg.com/vi/N42PuoXkjgA/hqdefault.jpg'],
#  ['Futuristic Marvel Technologies that will blow your mind\xa0| Marvel | Metaverse | GFG',
#   '610 views',
#   '1 month ago',
#   '/watch?v=1C5qpMkfeNw',
#   'https://i.ytimg.com/vi/1C5qpMkfeNw/hqdefault.jpg'],
#  ['Learn Lomuto Partition | Lecture - 19 | GeeksforGeeks',
#   '779 views',
#   '1 month ago',
#   '/watch?v=xew1z47P6OM',
#   'https://i.ytimg.com/vi/xew1z47P6OM/hqdefault.jpg'],
#  ['What is Dynamic Programming? |  Data Structures & Algorithms | GeeksforGeeks',
#   '908 views',
#   '1 month ago',
#   '/watch?v=ad6UqyoZ9Hk',
#   'https://i.ytimg.com/vi/ad6UqyoZ9Hk/hqdefault.jpg'],
#  ['Top 7 questions asked in Microsoft interviews😎 | Microsoft | Interview Questions | Career Tips | GFG',
#   '1.2K views',
#   '1 month ago',
#   '/watch?v=nZwVi7Affvc',
#   'https://i.ytimg.com/vi/nZwVi7Affvc/hqdefault.jpg'],
#  ['Learn Quick Sort (Naive Partition) in 5 Minutes | Sorting Playlist | Lecture -18 | GeeksforGeeks',
#   '521 views',
#   '1 month ago',
#   '/watch?v=kq3d0P6WxBo',
#   'https://i.ytimg.com/vi/kq3d0P6WxBo/hqdefault.jpg'],
#  ['Python vs Java | Which one you should choose\xa0in\xa02024? | Python | Java | Machine Learning | GFG',
#   '2.6K views',
#   '1 month ago',
#   '/watch?v=5IS1qwgUtPQ',
#   'https://i.ytimg.com/vi/5IS1qwgUtPQ/hqdefault.jpg'],
#  ['Count Inversion in Array | Lecture 17 | GeeksforGeeks',
#   '1K views',
#   '1 month ago',
#   '/watch?v=r0iq9vfZ6bA',
#   'https://i.ytimg.com/vi/r0iq9vfZ6bA/hqdefault.jpg'],
#  ['Why so many CEOs are from India? |\xa0Decoded | Google | Microsoft | Adobe | GFG',
#   '1.1K views',
#   '2 months ago',
#   '/watch?v=TpeDtIwGJeA',
#   'https://i.ytimg.com/vi/TpeDtIwGJeA/hqdefault.jpg'],
#  ['Learn Union Sort in 10 Minutes | Sorting Playlist | GeeksforGeeks',
#   '804 views',
#   '2 months ago',
#   '/watch?v=CfAGM0kQsGU',
#   'https://i.ytimg.com/vi/CfAGM0kQsGU/hqdefault.jpg'],
#  ['Three 90 Challenge | Hear from 90% Refund Winners | GeeksforGeeks',
#   '173K views',
#   '2 months ago',
#   '/watch?v=_QwpAU8k6Qw',
#   'https://i.ytimg.com/vi/_QwpAU8k6Qw/hqdefault.jpg'],
#  ['Intersection of Two Merge Sort Array | Free Tutorial | Lecture - 15 | GeeksforGeeks',
#   '669 views',
#   '2 months ago',
#   '/watch?v=dr5DHXTk7zc',
#   'https://i.ytimg.com/vi/dr5DHXTk7zc/hqdefault.jpg'],
#  ['Should you pursue Data Science in 2024? | Complete\xa0Roadmap | 50 LPA+ jobs | Data Science | GFG',
#   '1.2K views',
#   '2 months ago',
#   '/watch?v=TY1VeJSRk9I',
#   'https://i.ytimg.com/vi/TY1VeJSRk9I/hqdefault.jpg'],
#  ['Three 90 Challenge Back on Popular Demand | Refunds Processed worth INR 1 CR+ | GeeksforGeeks',
#   '257K views',
#   '2 months ago',
#   '/watch?v=fNuZ23MtCt8',
#   'https://i.ytimg.com/vi/fNuZ23MtCt8/hqdefault.jpg'],
#  ['Learn Merge Sort Analysis with @SandeepJainGfG  | GeeksforGeeks',
#   '468 views',
#   '2 months ago',
#   '/watch?v=Pb0L79nkdK0',
#   'https://i.ytimg.com/vi/Pb0L79nkdK0/hqdefault.jpg'],
#  ['Merge Sorting Algorithm with @SandeepJainGfG | Lecture 13 | GeeksforGeeks',
#   '814 views',
#   '2 months ago',
#   '/watch?v=ehvHKzU5Pcg',
#   'https://i.ytimg.com/vi/ehvHKzU5Pcg/hqdefault.jpg'],
#  ['Upto 50 lpa+ Package 🫨 | From Zero to DevOps Engineer - DevOps Roadmap 2024  | What\xa0is\xa0Devops? 🤔',
#   '908 views',
#   '2 months ago',
#   '/watch?v=S462Dnvlkz4',
#   'https://i.ytimg.com/vi/S462Dnvlkz4/hqdefault.jpg'],
#  ['Learn Merge Function of Merge Sort | Lecture 12 | GeeksforGeeks',
#   '546 views',
#   '2 months ago',
#   '/watch?v=uvabUx1T-Lw',
#   'https://i.ytimg.com/vi/uvabUx1T-Lw/hqdefault.jpg'],
#  ['How to Merge two SORTED ARRAYS with @SandeepJainGfG  | GeeksforGeeks',
#   '989 views',
#   '2 months ago',
#   '/watch?v=pUw1Id6zNTE',
#   'https://i.ytimg.com/vi/pUw1Id6zNTE/hqdefault.jpg'],
#  ['Whooping Salaries of CyberHub Gurgaon Employees and their Office Crushes| StreetStyle |CyberHub |GFG',
#   '1.7K views',
#   '2 months ago',
#   '/watch?v=HWnw7VdeVZ4',
#   'https://i.ytimg.com/vi/HWnw7VdeVZ4/hqdefault.jpg'],
#  ['Learn Merge Sort in 2 minutes | Episode - 10 | @SandeepJainGfG | Geeksforgeeks',
#   '784 views',
#   '2 months ago',
#   '/watch?v=EN8VDyLzs2s',
#   'https://i.ytimg.com/vi/EN8VDyLzs2s/hqdefault.jpg'],
#  ['Learn INSERTION SORT in 10 minutes | @SandeepJainGfG | Episode- 9 | GeeksforGeeks',
#   '689 views',
#   '2 months ago',
#   '/watch?v=bJ_Q23Wlj_Q',
#   'https://i.ytimg.com/vi/bJ_Q23Wlj_Q/hqdefault.jpg'],
#  ["Become Zero to Hero in Digital Marketing😮 | Learn the Why's and How's of Digital Marketing | GFG",
#   '819 views',
#   '2 months ago',
#   '/watch?v=073j2jj7jbg',
#   'https://i.ytimg.com/vi/073j2jj7jbg/hqdefault.jpg'],
#  ['Learn Selection Sort Algorithm | @SandeepJainGfG | Episode - 8 |  GeeksforGeeks',
#   '1.2K views',
#   '2 months ago',
#   '/watch?v=WYVKZ4Mla5c',
#   'https://i.ytimg.com/vi/WYVKZ4Mla5c/hqdefault.jpg'],
#  ['Learn Bubble Sort in 12 minutes | @SandeepJainGfG | Lecture 7 | GeeksforGeeks',
#   '1.1K views',
#   '2 months ago',
#   '/watch?v=dMonTS71mEY',
#   'https://i.ytimg.com/vi/dMonTS71mEY/hqdefault.jpg'],
#  ['Lecture-6 Learn Stability in SORTING - Beginners to Advance | GeeksforGeeks',
#   '731 views',
#   '2 months ago',
#   '/watch?v=voH3da1RvbA',
#   'https://i.ytimg.com/vi/voH3da1RvbA/hqdefault.jpg'],
#  ['GeeksforGeeks Classroom Program | Delhi/NCR | Pune | Bengaluru | Offline Coding Classes Near You!',
#   '71K views',
#   '2 months ago',
#   '/watch?v=-R64PWJPf2k',
#   'https://i.ytimg.com/vi/-R64PWJPf2k/hqdefault.jpg'],
#  ['Lecture-5 Mastering Sorting Algorithms with Java: From Collections.sort to Custom Comparators',
#   '1K views',
#   '2 months ago',
#   '/watch?v=VSy4TN2jyzE',
#   'https://i.ytimg.com/vi/VSy4TN2jyzE/hqdefault.jpg'],
#  ['Lecture-4  Arrays.sort() in Java Explained |  Primitive vs. Non-Primitive | GeeksforGeeks',
#   '1K views',
#   '2 months ago',
#   '/watch?v=6mwz4JQ6Z50',
#   'https://i.ytimg.com/vi/6mwz4JQ6Z50/hqdefault.jpg'],
#  ['Lecture-3 Java Sorting Explained: Arrays vs. Collections, Stability, and Algorithms | GeeksforGeeks',
#   '1.3K views',
#   '3 months ago',
#   '/watch?v=mUX5IfNwhjg',
#   'https://i.ytimg.com/vi/mUX5IfNwhjg/hqdefault.jpg'],
#  ["Lecture- 2 Mastering Sorting in C++: STL 'sort' Function Explained | GeeksforGeeks",
#   '1.3K views',
#   '3 months ago',
#   '/watch?v=tmESfVUaTog',
#   'https://i.ytimg.com/vi/tmESfVUaTog/hqdefault.jpg'],
#  ['7 Game-Changing Productivity Tools You Need to Try! 🚀 | Maximize Your Efficiency | GFG',
#   '1.5K views',
#   '3 months ago',
#   '/watch?v=gH-7ezHeuEo',
#   'https://i.ytimg.com/vi/gH-7ezHeuEo/hqdefault.jpg'],
#  ['Lecture -1 Introduction to Sorting Algorithms - Overview & Special Cases| GeeksforGeeks',
#   '5.9K views',
#   '3 months ago',
#   '/watch?v=cqBW7BgN7Zs',
#   'https://i.ytimg.com/vi/cqBW7BgN7Zs/hqdefault.jpg'],
#  ['Get 40LPA+ Jobs - Top MERN Stack Interview Questions 2024 🧑\u200d💻| MongoDB |ReactJS | ExpressJS |NodeJS',
#   '1.2K views',
#   '3 months ago',
#   '/watch?v=EhjCmg7qiTk',
#   'https://i.ytimg.com/vi/EhjCmg7qiTk/hqdefault.jpg'],
#  ['All about Product Management Roles 🧑\u200d💻  | Skills and Resources Explained |#noncodingjobs #prodman',
#   '1.5K views',
#   '3 months ago',
#   '/watch?v=Jk2g9Drr1rI',
#   'https://i.ytimg.com/vi/Jk2g9Drr1rI/hqdefault.jpg'],
#  ['How to Create a Job-Winning Resume: A Complete Guide 🫨 | Resume Making | Career Tips | GFG',
#   '1.5K views',
#   '3 months ago',
#   '/watch?v=ZEGi4IXY2ho',
#   'https://i.ytimg.com/vi/ZEGi4IXY2ho/hqdefault.jpg'],
#  ['Upto 40 LPA Jobs from Personal Branding 💸 | Linkedin, Youtube, Twitter, Freelancing 🚀 | GFG',
#   '1.6K views',
#   '3 months ago',
#   '/watch?v=W15T5GRf238',
#   'https://i.ytimg.com/vi/W15T5GRf238/hqdefault.jpg'],
#  ["9 High Paying Jobs AI Can't Replace 💸💡 High Demand Jobs 2024 | Geeks for Geeks",
#   '1.8K views',
#   '3 months ago',
#   '/watch?v=mPNpCXHjdkw',
#   'https://i.ytimg.com/vi/mPNpCXHjdkw/hqdefault.jpg'],
#  ['Upto 20 LPA Jobs For Freshers With These Top 7 Skills | Salary, Scope, Roles & Responsibility etc.',
#   '1.5K views',
#   '3 months ago',
#   '/watch?v=Q6QXk-rrW0M',
#   'https://i.ytimg.com/vi/Q6QXk-rrW0M/hqdefault.jpg'],
#  ['10-12 LPA JOBS for Freshers | Applications Closing Soon! Tech + Non Tech Roles | Job Vacancy 2024',
#   '3.2K views',
#   '4 months ago',
#   '/watch?v=G_LoL_bBcQE',
#   'https://i.ytimg.com/vi/G_LoL_bBcQE/hqdefault.jpg'],
#  ['BUILD YOUR OWN UI/UX WEBSITE USING React.js | MERN Projects | GeeksforGeeks',
#   '3K views',
#   '4 months ago',
#   '/watch?v=uZ9JiGzq3mM',
#   'https://i.ytimg.com/vi/uZ9JiGzq3mM/hqdefault.jpg'],
#  ['Get DREAM JOB with these NETWORKING TIPS! 💸💡LinkedIn, Referrals, Cold Messaging, Networking Events',
#   '1.3K views',
#   '4 months ago',
#   '/watch?v=zPqMnLhkfp4',
#   'https://i.ytimg.com/vi/zPqMnLhkfp4/hqdefault.jpg'],
#  ['RECURSION PRACTICE PROBLEM | Recursive Algorithm | DSA Course | GeeksforGeeks',
#   '886 views',
#   '4 months ago',
#   '/watch?v=Hpf6mr-7_5k',
#   'https://i.ytimg.com/vi/Hpf6mr-7_5k/hqdefault.jpg'],
#  ['Best Startup Ideas in College 2024 💸🚀| Earn Better than Placement? 🤑 | Guide, Ideas, Funding etc',
#   '1.5K views',
#   '4 months ago',
#   '/watch?v=G_gowXgOFRA',
#   'https://i.ytimg.com/vi/G_gowXgOFRA/hqdefault.jpg'],
#  ['Get 20LPA+ Jobs with these 5 Unique Project Ideas💡| Projects for Internships and Placements',
#   '3.1K views',
#   '4 months ago',
#   '/watch?v=5mw5IzWTFs0',
#   'https://i.ytimg.com/vi/5mw5IzWTFs0/hqdefault.jpg'],
#  ['Hate Coding? Upto 44 LPA Non Tech Jobs in 2024 💸 | Skills, Role and Salary Expected.',
#   '1.8K views',
#   '4 months ago',
#   '/watch?v=DMhSsL3-SLk',
#   'https://i.ytimg.com/vi/DMhSsL3-SLk/hqdefault.jpg'],
#  ['Asking Coding Questions to Students Worth 20k Prices 🥳🤑| Kaun Banega Codepati ? 💸',
#   '1.2K views',
#   '4 months ago',
#   '/watch?v=a5C5lCGTIrs',
#   'https://i.ytimg.com/vi/a5C5lCGTIrs/hqdefault.jpg'],
#  ['Data Analyst vs Data Scientist vs Data Engineer | Differences, Skills, Salary & Responsibilities 💸',
#   '7.6K views',
#   '4 months ago',
#   '/watch?v=EHmXVwjtgPs',
#   'https://i.ytimg.com/vi/EHmXVwjtgPs/hqdefault.jpg'],
#  ['Top 8 Remote Jobs Websites For Freshers 🚀 |  Earn in Dollars | How to Get Remote Jobs in 2024?',
#   '3K views',
#   '4 months ago',
#   '/watch?v=OIsIZ1w7aTU',
#   'https://i.ytimg.com/vi/OIsIZ1w7aTU/hqdefault.jpg'],
#  ['5 GENUINE Ways to EARN 40K+ as Student 💸🚀 | Pay Your College Fees | Earn Online ✅',
#   '2.1K views',
#   '4 months ago',
#   '/watch?v=WEm6-g3dCBc',
#   'https://i.ytimg.com/vi/WEm6-g3dCBc/hqdefault.jpg'],
#  ['Image Classification using CNN | Machine Learning Projects | GeeksforGeeks',
#   '3.9K views',
#   '4 months ago',
#   '/watch?v=qm56XcRBXWc',
#   'https://i.ytimg.com/vi/qm56XcRBXWc/hqdefault.jpg'],
#  ['Does CGPA Matters in Placement? | Low CGPA? Tier 3? Eligibility? | IT Jobs & Companies for Low CGPA',
#   '3.1K views',
#   '4 months ago',
#   '/watch?v=mrap_vC0ZqU',
#   'https://i.ytimg.com/vi/mrap_vC0ZqU/hqdefault.jpg'],
#  ['15 LPA+ Fresher JOBS in Java 🚀 | BEST ROADMAP from Scratch | Geeks For Geeks',
#   '5K views',
#   '4 months ago',
#   '/watch?v=BWc2DeBaYuQ',
#   'https://i.ytimg.com/vi/BWc2DeBaYuQ/hqdefault.jpg'],
#  ['Top 10 Highest Paying Tech Jobs in India 2024 💸🚀 | Geeks For Geeks',
#   '2K views',
#   '4 months ago',
#   '/watch?v=tGSmvrS_TJk',
#   'https://i.ytimg.com/vi/tGSmvrS_TJk/hqdefault.jpg'],
#  ['Build an Ecommerce Website Like ZARA using React.js | MERN Projects | GeeksforGeeks',
#   '13K views',
#   '4 months ago',
#   '/watch?v=jk2rhtBJ5S4',
#   'https://i.ytimg.com/vi/jk2rhtBJ5S4/hqdefault.jpg'],
#  ['How to Start Coding in 2024? 🚀 | Programming Language for Beginners | Geeks for Geeks',
#   '3.5K views',
#   '4 months ago',
#   '/watch?v=dAzVSu5zavU',
#   'https://i.ytimg.com/vi/dAzVSu5zavU/hqdefault.jpg'],
#  ['3 Reasons Students QUIT Coding | How to Code Consistently ? | GeeksforGeeks',
#   '1.8K views',
#   '4 months ago',
#   '/watch?v=oM0HOxae8_A',
#   'https://i.ytimg.com/vi/oM0HOxae8_A/hqdefault.jpg'],
#  ['Is coding worth it in 2024? 😥 | AI better than coders? | Tech Layoffs & Recession',
#   '2.7K views',
#   '5 months ago',
#   '/watch?v=GD8xHjxnyK8',
#   'https://i.ytimg.com/vi/GD8xHjxnyK8/hqdefault.jpg'],
#  ['Build a Food Delivery Website using React.js | MERN Stack Projects | GeeksforGeeks',
#   '23K views',
#   '5 months ago',
#   '/watch?v=bd5DewlahnE',
#   'https://i.ytimg.com/vi/bd5DewlahnE/hqdefault.jpg'],
#  ['5 Ways to Prepare for Layoffs in 2024! | AI Tools | Upskilling | Side Hustles',
#   '1.6K views',
#   '5 months ago',
#   '/watch?v=XbG-Z0gxrjs',
#   'https://i.ytimg.com/vi/XbG-Z0gxrjs/hqdefault.jpg'],
#  ['Get Hired From Linkedin in 2024 | Best Linkedin Profile Creation | Skills, Experiences & Networking🚀',
#   '3K views',
#   '5 months ago',
#   '/watch?v=2QbhA2mthy0',
#   'https://i.ytimg.com/vi/2QbhA2mthy0/hqdefault.jpg'],
#  ['High-Paying Tech Jobs Using AI | AI Tools for Coders | Geeks for Geeks',
#   '2.1K views',
#   '5 months ago',
#   '/watch?v=PekLwtZVi3k',
#   'https://i.ytimg.com/vi/PekLwtZVi3k/hqdefault.jpg'],
#  ['Web Dev vs App Dev in 2024? Which has more Salary ?🤔 | Career Scope & Skills | Geeks for Geeks',
#   '1.9K views',
#   '5 months ago',
#   '/watch?v=hRTRjWm-2pQ',
#   'https://i.ytimg.com/vi/hRTRjWm-2pQ/hqdefault.jpg'],
#  ['Build a Fitness Tracker Website using React JS |MERN Projects |GeeksforGeeks',
#   '28K views',
#   '5 months ago',
#   '/watch?v=HISjHTE2vnM',
#   'https://i.ytimg.com/vi/HISjHTE2vnM/hqdefault.jpg'],
#  ['Top 7 High Paying Tech Jobs in 2024 | Skills and Salary Expected | Geeks for Geeks',
#   '39K views',
#   '5 months ago',
#   '/watch?v=BS-y9ieR-mQ',
#   'https://i.ytimg.com/vi/BS-y9ieR-mQ/hqdefault.jpg'],
#  ['GATE AIR 21 Shares her secret to become a GATE Topper | GATE Topper Interview | GeeksforGeeks',
#   '1.7K views',
#   '5 months ago',
#   '/watch?v=M5tEUGFpCg0',
#   'https://i.ytimg.com/vi/M5tEUGFpCg0/hqdefault.jpg'],
#  ['5 Ways to Become Top 1% Coders in 2024 | Get Jobs in IT | Geeks for Geeks',
#   '1.8K views',
#   '5 months ago',
#   '/watch?v=OrNjShjUdow',
#   'https://i.ytimg.com/vi/OrNjShjUdow/hqdefault.jpg'],
#  ['Tips to ace your tech job search | Resume tips by expert from @indeedindiaofficial   | GeeksforGeeks',
#   '1K views',
#   '5 months ago',
#   '/watch?v=mh7En1ir_XM',
#   'https://i.ytimg.com/vi/mh7En1ir_XM/hqdefault.jpg'],
#  ['Three 90 Challenge Back with Benefits | GeeksforGeeks',
#   '57K views',
#   '5 months ago',
#   '/watch?v=-d-ZuuF8czQ',
#   'https://i.ytimg.com/vi/-d-ZuuF8czQ/hqdefault.jpg'],
#  ['7 JAVASCRIPT Concepts Every DEVELOPER Must Know! | GeeksforGeeks',
#   '980 views',
#   '5 months ago',
#   '/watch?v=YxRErpzCa7c',
#   'https://i.ytimg.com/vi/YxRErpzCa7c/hqdefault.jpg'],
#  ['MOVIE RECOMMENDATION SYSTEM Using Machine Learning | Machine Leaning Projects | GeeksforGeeks',
#   '5.4K views',
#   '5 months ago',
#   '/watch?v=kxT8AursXXw',
#   'https://i.ytimg.com/vi/kxT8AursXXw/hqdefault.jpg'],
#  ['MASTERING RECURSION | Recursive Algorithm | DSA Course | GeeksforGeeks',
#   '1.2K views',
#   '5 months ago',
#   '/watch?v=zwGcJ62lZ5g',
#   'https://i.ytimg.com/vi/zwGcJ62lZ5g/hqdefault.jpg'],
#  ['Is Software Engineering Dead ? - Meet Devin by Cognition Labs | GeeksforGeeks',
#   '1.6K views',
#   '5 months ago',
#   '/watch?v=i8w_2n1GH44',
#   'https://i.ytimg.com/vi/i8w_2n1GH44/hqdefault.jpg'],
#  ['7 BEST AI Tools for Developers in 2024 | GeeksforGeeks',
#   '1.6K views',
#   '6 months ago',
#   '/watch?v=mpIDwAT7m_0',
#   'https://i.ytimg.com/vi/mpIDwAT7m_0/hqdefault.jpg'],
#  ['3D PORTFOLIO WEBSITE using React and Three JS | GeeksforGeeks',
#   '34K views',
#   '6 months ago',
#   '/watch?v=udtb67DKyq0',
#   'https://i.ytimg.com/vi/udtb67DKyq0/hqdefault.jpg'],
#  ['FAKE NEWS DETECTION Using MACHINE LEARNING | Machine Learning Projects | GeeksforGeeks',
#   '14K views',
#   '6 months ago',
#   '/watch?v=CkiXRQvz4Z4',
#   'https://i.ytimg.com/vi/CkiXRQvz4Z4/hqdefault.jpg'],
#  ['HEART DISEASE DETECTION using MACHINE LEARNING | Machine Learning Projects | GeeksforGeeks',
#   '3.2K views',
#   '6 months ago',
#   '/watch?v=F_9gGyCs3YY',
#   'https://i.ytimg.com/vi/F_9gGyCs3YY/hqdefault.jpg'],
#  ['WHY LEARN PYTHON in 2024? | Benefits of Learning Python | GeeksforGeeks',
#   '1.7K views',
#   '6 months ago',
#   '/watch?v=AmU9Zi6TNrs',
#   'https://i.ytimg.com/vi/AmU9Zi6TNrs/hqdefault.jpg'],
#  ['Doctor Aaye #successsepareshan Rohan ko Dekhne...',
#   '395K views',
#   '6 months ago',
#   '/watch?v=zbBALFXGy4Y',
#   'https://i.ytimg.com/vi/zbBALFXGy4Y/hqdefault.jpg'],
#  ['ATS Friendly Resume for Placement in 2024!!! GeeksforGeeks',
#   '1.2K views',
#   '6 months ago',
#   '/watch?v=GF69ZVc1icg',
#   'https://i.ytimg.com/vi/GF69ZVc1icg/hqdefault.jpg'],
#  ['React JS Made Easy with ChatGPT | GeeksforGeeks',
#   '1.8K views',
#   '6 months ago',
#   '/watch?v=MSmDIkWEtoc',
#   'https://i.ytimg.com/vi/MSmDIkWEtoc/hqdefault.jpg'],
#  ['TREE PRACTICE PROBLEMS | Tree Traversal Algorithms | DSA Course | GeeksforGeeks',
#   '2.7K views',
#   '6 months ago',
#   '/watch?v=0lLmU-VqXzk',
#   'https://i.ytimg.com/vi/0lLmU-VqXzk/hqdefault.jpg'],
#  ['GATE CS 2024 ANSWER KEY OUT!! Detailed Paper Discussion - Shift 1 | GeeksforGeeks',
#   '1.1K views',
#   '6 months ago',
#   '/watch?v=9fTvjjI67Rk',
#   'https://i.ytimg.com/vi/9fTvjjI67Rk/hqdefault.jpg'],
#  ['GATE DS & AI 2024 Response Sheet Out | GATE DS & AI | Data Science GATE Response key | GeeksforGeeks',
#   '1.1K views',
#   '6 months ago',
#   '/watch?v=iFGoMXC4Cxo',
#   'https://i.ytimg.com/vi/iFGoMXC4Cxo/hqdefault.jpg'],
#  ['Kyun Hai Rohan #successsepareshan? | GeeksforGeeks',
#   '275K views',
#   '6 months ago',
#   '/watch?v=v41P3Y5Xol8',
#   'https://i.ytimg.com/vi/v41P3Y5Xol8/hqdefault.jpg'],
#  ['TREE DATA STRUCTURES | What is Tree? | DSA Course | GeeksforGeeks',
#   '6.8K views',
#   '6 months ago',
#   '/watch?v=AylOfzYJ2qE',
#   'https://i.ytimg.com/vi/AylOfzYJ2qE/hqdefault.jpg'],
#  ['Three 90 Challenge Extended | 100+ Refunds Processed! | GeeksforGeeks',
#   '33K views',
#   '7 months ago',
#   '/watch?v=FVCERWiQSDY',
#   'https://i.ytimg.com/vi/FVCERWiQSDY/hqdefault.jpg'],
#  ['TYPESCRIPT vs JAVASCRIPT | Which one to Choose? | GeeksforGeeks',
#   '1.1K views',
#   '7 months ago',
#   '/watch?v=BFf8n2RrKtM',
#   'https://i.ytimg.com/vi/BFf8n2RrKtM/hqdefault.jpg'],
#  ["Python's Map Function Explained with Examples | Python Tutorial |  GeeksforGeeks",
#   '1K views',
#   '7 months ago',
#   '/watch?v=L66_EOxzLKI',
#   'https://i.ytimg.com/vi/L66_EOxzLKI/hqdefault.jpg'],
#  ['Build your own AI image Generation App using MERN | MERN Stack Project | GeeksforGeeks',
#   '42K views',
#   '7 months ago',
#   '/watch?v=stcihX2eavw',
#   'https://i.ytimg.com/vi/stcihX2eavw/hqdefault.jpg'],
#  ['Strategies To Find A Job FAST! | Job Hunt Tips | How People Get Good Jobs | GeeksforGeeks',
#   '898 views',
#   '7 months ago',
#   '/watch?v=rFXVb2-Rj5k',
#   'https://i.ytimg.com/vi/rFXVb2-Rj5k/hqdefault.jpg'],
#  ['Make your Resume Strong with these DSA Projects | Best DSA Projects for your Resume | GeeksforGeeks',
#   '18K views',
#   '7 months ago',
#   '/watch?v=NjUteXHoOXk',
#   'https://i.ytimg.com/vi/NjUteXHoOXk/hqdefault.jpg'],
#  ['Top TECH TRENDS & CAREERS in 2024!!! GeeksforGeeks',
#   '846 views',
#   '7 months ago',
#   '/watch?v=FAluaVzy4VM',
#   'https://i.ytimg.com/vi/FAluaVzy4VM/hqdefault.jpg'],
#  ['GeeksforGeeks Bloopers!! The Making of Quality Content',
#   '834 views',
#   '7 months ago',
#   '/watch?v=zakV-wfdPYM',
#   'https://i.ytimg.com/vi/zakV-wfdPYM/hqdefault.jpg'],
#  ['APTITUDE & REASONING | GATE 2024 Ultimate Revision | PYQ and Sample Questions GATE',
#   '1.6K views',
#   '7 months ago',
#   '/watch?v=CaAjf_RE9ew',
#   'https://i.ytimg.com/vi/CaAjf_RE9ew/hqdefault.jpg'],
#  ['Meet The Youngest CTO Of India- Shivansh Saxena | GeeksforGeeks',
#   '3.7K views',
#   '7 months ago',
#   '/watch?v=5YlR3yZV9bE',
#   'https://i.ytimg.com/vi/5YlR3yZV9bE/hqdefault.jpg'],
#  ['Top 3 Things College Students FEAR!!',
#   '115K views',
#   '7 months ago',
#   '/watch?v=mOkFtGLA9q8',
#   'https://i.ytimg.com/vi/mOkFtGLA9q8/hqdefault.jpg'],
#  ['DATA SCIENCE PROJECTS Made Easy with COLAB AI | Generative AI | GeeksforGeeks',
#   '2.5K views',
#   '7 months ago',
#   '/watch?v=Gt5ZkoFrgyE',
#   'https://i.ytimg.com/vi/Gt5ZkoFrgyE/hqdefault.jpg'],
#  ['Top VS Code Extensions for Web Developer in 2024!! GeeksforGeeks',
#   '2.3K views',
#   '7 months ago',
#   '/watch?v=l-LJucxS8Mc',
#   'https://i.ytimg.com/vi/l-LJucxS8Mc/hqdefault.jpg'],
#  ['LINKED LIST PRACTICE QUESTIONS | Operations on Linked List | DSA Problems | GeeksforGeeks',
#   '3.7K views',
#   '8 months ago',
#   '/watch?v=TnV34Lfdk7k',
#   'https://i.ytimg.com/vi/TnV34Lfdk7k/hqdefault.jpg'],
#  ['Three 90 Challenge - Q&A with Sandeep Jain Sir | GeeksforGeeks #commitwithgfg',
#   '5.9K views',
#   '8 months ago',
#   '/watch?v=KyUbJ4aoIgQ',
#   'https://i.ytimg.com/vi/KyUbJ4aoIgQ/hqdefault.jpg'],
#  ['Secrets to CONSISTENCY, COMMITMENT, and CAREER SUCCESS! #commitwithgfg',
#   '2.5K views',
#   '8 months ago',
#   '/watch?v=6jhkJoOnMCc',
#   'https://i.ytimg.com/vi/6jhkJoOnMCc/hqdefault.jpg'],
#  ['2024 Will be the YEAR for CODERS!! #commitwithgfg',
#   '1.4K views',
#   '8 months ago',
#   '/watch?v=Nozck3wIMCo',
#   'https://i.ytimg.com/vi/Nozck3wIMCo/hqdefault.jpg'],
#  ['WHAT IS LINKED LIST? | Linked List Data Structures | DSA Course | GeeksforGeeks',
#   '7.3K views',
#   '8 months ago',
#   '/watch?v=MCG7S2fGUeU',
#   'https://i.ytimg.com/vi/MCG7S2fGUeU/hqdefault.jpg'],
#  ['Three 90 Challenge !! Transform your 2024 with GeeksforGeeks #commitwithgfg',
#   '11K views',
#   '8 months ago',
#   '/watch?v=Vtxq-yHdKpA',
#   'https://i.ytimg.com/vi/Vtxq-yHdKpA/hqdefault.jpg'],
#  ['10 Best PROGRAMMING LANGUAGES to Learn in 2024 | GeeksforGeeks',
#   '3.5K views',
#   '8 months ago',
#   '/watch?v=ehXa1Hxxu3Y',
#   'https://i.ytimg.com/vi/ehXa1Hxxu3Y/hqdefault.jpg'],
#  ['5 BEST GITHUB REPOSITORIES Every DEVELOPER Must Know! | GeeksforGeeks',
#   '2.9K views',
#   '8 months ago',
#   '/watch?v=xvUopUeVS0U',
#   'https://i.ytimg.com/vi/xvUopUeVS0U/hqdefault.jpg'],
#  ['Ready to #commitwithgfg ?',
#   '27K views',
#   '8 months ago',
#   '/watch?v=lbveOrbHgto',
#   'https://i.ytimg.com/vi/lbveOrbHgto/hqdefault.jpg'],
#  ['How to Use GOOGLE COLAB | Google Colab Tutorials for Beginners | GeeksforGeeks',
#   '3.5K views',
#   '8 months ago',
#   '/watch?v=TqqkZLHoY0o',
#   'https://i.ytimg.com/vi/TqqkZLHoY0o/hqdefault.jpg'],
#  ['Journey from an SDE at PAYTM to MICROSOFT | Software Developer Experience | GeeksforGeeks',
#   '1.8K views',
#   '8 months ago',
#   '/watch?v=0mRyTDhxe_s',
#   'https://i.ytimg.com/vi/0mRyTDhxe_s/hqdefault.jpg'],
#  ['What is DEVOPS and DEPLOYMENT? | Importance and Role of DevOps in Web Development | GeeksforGeeks',
#   '915 views',
#   '8 months ago',
#   '/watch?v=NoxexEfck3g',
#   'https://i.ytimg.com/vi/NoxexEfck3g/hqdefault.jpg'],
#  ['GeeksforGeeks In a Review 2023 | GfG Rewind 2023',
#   '2.3K views',
#   '8 months ago',
#   '/watch?v=q_kEa8oBo2A',
#   'https://i.ytimg.com/vi/q_kEa8oBo2A/hqdefault.jpg'],
#  ['How to Implement PICTURE IN PICTURE (PIP) MODE in Flutter Apps | Flutter Projects | GeeksforGeeks',
#   '1.8K views',
#   '8 months ago',
#   '/watch?v=eBEdJCsqusI',
#   'https://i.ytimg.com/vi/eBEdJCsqusI/hqdefault.jpg'],
#  ['How to Integrate RAZORPAY PAYMENT GATEWAY in your Flutter App | Flutter Projects | GeeksforGeeks',
#   '12K views',
#   '9 months ago',
#   '/watch?v=1XFGgHunNrk',
#   'https://i.ytimg.com/vi/1XFGgHunNrk/hqdefault.jpg'],
#  ['Career in DATA ANALYTICS | Insights from a DATA ANALYST at AMERICAN EXPRESS | GeeksforGeeks',
#   '4.3K views',
#   '9 months ago',
#   '/watch?v=1zHWzyI7TC0',
#   'https://i.ytimg.com/vi/1zHWzyI7TC0/hqdefault.jpg'],
#  ['All About WEB SECURITY | Web Security for Full Stack Developers | GeeksforGeeks',
#   '1K views',
#   '9 months ago',
#   '/watch?v=578Pzg7tVF4',
#   'https://i.ytimg.com/vi/578Pzg7tVF4/hqdefault.jpg'],
#  ['What is VERSION CONTROL and GIT? Web Development Explained | GeeksforGeeks',
#   '5K views',
#   '9 months ago',
#   '/watch?v=jxbGBOo4GDs',
#   'https://i.ytimg.com/vi/jxbGBOo4GDs/hqdefault.jpg'],
#  ['Build Your Own GUI CALENDAR with Tkinter in Python | Python Projects | GeeksforGeeks',
#   '2K views',
#   '9 months ago',
#   '/watch?v=W2S8NnlJtgk',
#   'https://i.ytimg.com/vi/W2S8NnlJtgk/hqdefault.jpg'],
#  ['Implementing Simple and Custom ALERT DIALOG BOX in Flutter Apps | Flutter Projects | GeeksforGeeks',
#   '1.6K views',
#   '9 months ago',
#   '/watch?v=b6iw6dLQ7AU',
#   'https://i.ytimg.com/vi/b6iw6dLQ7AU/hqdefault.jpg'],
#  ['How to EXTRACT AUDIO from VIDEO using Python | Python Projects | GeeksforGeeks',
#   '3.5K views',
#   '9 months ago',
#   '/watch?v=SrPi0FrmGiE',
#   'https://i.ytimg.com/vi/SrPi0FrmGiE/hqdefault.jpg'],
#  ['How to Create LANGUAGE TRANSLATOR Application in Flutter | Flutter Projects | GeeksforGeeks',
#   '7.7K views',
#   '9 months ago',
#   '/watch?v=CeupjFXlFiQ',
#   'https://i.ytimg.com/vi/CeupjFXlFiQ/hqdefault.jpg'],
#  ['🍷 WINE QUALITY PREDICTION using RANDOM FOREST Algorithm | Machine Learning Projects | GeeksforGeeks',
#   '2.3K views',
#   '9 months ago',
#   '/watch?v=MyllYgc-kh8',
#   'https://i.ytimg.com/vi/MyllYgc-kh8/hqdefault.jpg'],
#  ['Create a QR CODE SCANNER and GENERATOR Application using Flutter | Flutter Projects | GeeksforGeeks',
#   '30K views',
#   '9 months ago',
#   '/watch?v=hm5JfFhiXL8',
#   'https://i.ytimg.com/vi/hm5JfFhiXL8/hqdefault.jpg'],
#  ['Create AI DESKTOP VIRTUAL ASSISTANT using Python and Tkinter | Python Projects | GeeksforGeeks',
#   '14K views',
#   '9 months ago',
#   '/watch?v=tZl1_AcC7Dw',
#   'https://i.ytimg.com/vi/hm5JfFhiXL8/hqdefault.jpg'],
#  ['Graph Practice Problems | Graph Data Structure | DSA Course | GeeksforGeeks',
#   '7K views',
#   '9 months ago',
#   '/watch?v=pCmsQVHYXK0',
#   'https://i.ytimg.com/vi/hm5JfFhiXL8/hqdefault.jpg'],
#  ['Face Detection using Python and OpenCV with webcam | Python Projects | GeeksforGeeks',
#   '6.2K views',
#   '9 months ago',
#   '/watch?v=129exLkKeks',
#   'https://i.ytimg.com/vi/hm5JfFhiXL8/hqdefault.jpg'],
#  ['Plagiarism Detection using Python | Python Projects | GeeksforGeeks',
#   '5.2K views',
#   '9 months ago',
#   '/watch?v=QFQItyHsxZY',
#   'https://i.ytimg.com/vi/hm5JfFhiXL8/hqdefault.jpg'],
#  ['Weapon Detection Using Python-OpenCV | Python Projects | GeeksforGeeks',
#   '16K views',
#   '9 months ago',
#   '/watch?v=xlcNMlyN34g',
#   'https://i.ytimg.com/vi/hm5JfFhiXL8/hqdefault.jpg'],
#  ['TITANIC SURVIVAL PREDICTION using TensorFlow | Machine Learning Projects | GeeksforGeeks',
#   '2.1K views',
#   '9 months ago',
#   '/watch?v=cRYSIR6LaNQ',
#   'https://i.ytimg.com/vi/hm5JfFhiXL8/hqdefault.jpg'],
#  ['What is BACKEND DEVELOPMENT? | Explained in 60 seconds | Full Stack Concepts | GeeksforGeeks',
#   '1.8K views',
#   '9 months ago',
#   '/watch?v=C2u6_wOYlPc',
#   'https://i.ytimg.com/vi/C2u6_wOYlPc/hqdefault.jpg'],
#  ['STOCK PRICE PREDICTION using Machine Learning📈 | Machine Learning Projects | GeeksforGeeks',
#   '34K views',
#   '9 months ago',
#   '/watch?v=tn07dCSFOfQ',
#   'https://i.ytimg.com/vi/tn07dCSFOfQ/hqdefault.jpg'],
#  ['What is FRONTEND DEVELOPMENT? | Explained in 60 seconds | Full Stack Concepts | GeeksforGeeks',
#   '1.6K views',
#   '9 months ago',
#   '/watch?v=IiM10iV_Zug',
#   'https://i.ytimg.com/vi/IiM10iV_Zug/hqdefault.jpg'],
#  ['Air Quality Index Prediction in Python | Machine Learning Projects | GeeksforGeeks',
#   '14K views',
#   '9 months ago',
#   '/watch?v=0myaZxl4XWw',
#   'https://i.ytimg.com/vi/0myaZxl4XWw/hqdefault.jpg'],
#  ['TWITTER SENTIMENT ANALYSIS (NLP) | Machine Learning Projects | GeeksforGeeks',
#   '89K views',
#   '10 months ago',
#   '/watch?v=4YGkfAd2iXM',
#   'https://i.ytimg.com/vi/4YGkfAd2iXM/hqdefault.jpg'],
#  ['Diabetes Prediction in Machine Learning using Python | Machine Learning Projects | GeeksforGeeks',
#   '14K views',
#   '10 months ago',
#   '/watch?v=AxYgzie4x2E',
#   'https://i.ytimg.com/vi/AxYgzie4x2E/hqdefault.jpg'],
#  ['Stack Practice Question | Parenthesis Checker | Learn DSA Concepts | GeeksforGeeks',
#   '2.9K views',
#   '10 months ago',
#   '/watch?v=2ay2GCrmf9E',
#   'https://i.ytimg.com/vi/2ay2GCrmf9E/hqdefault.jpg'],
#  ['Build a Stopwatch using HTML, CSS, and JS | GeeksforGeeks',
#   '1.3K views',
#   '10 months ago',
#   '/watch?v=DR5tJWig0AQ',
#   'https://i.ytimg.com/vi/DR5tJWig0AQ/hqdefault.jpg'],
#  ['WHAT IS STACK? | Stack Data Structures | DSA Course | GeeksforGeeks',
#   '5.8K views',
#   '10 months ago',
#   '/watch?v=lhhyE7NVcbg',
#   'https://i.ytimg.com/vi/lhhyE7NVcbg/hqdefault.jpg'],
#  ['Meet A Data Scientist with 5 Years+ Experience | Ft.Tavishi Jaglan | GeeksforGeeks',
#   '2.3K views',
#   '10 months ago',
#   '/watch?v=4_u-xcfqpcA',
#   'https://i.ytimg.com/vi/4_u-xcfqpcA/hqdefault.jpg'],
#  ['Master Data Science Concepts: Apache Kafka in 60 Seconds | Data Science Crash Course | GeeksforGeeks',
#   '1K views',
#   '10 months ago',
#   '/watch?v=Li0wAG3hORQ',
#   'https://i.ytimg.com/vi/Li0wAG3hORQ/hqdefault.jpg'],
#  ['Master Data Science Concepts: Apache Flume in 60 Seconds | Data Science Crash Course | GeeksforGeeks',
#   '776 views',
#   '10 months ago',
#   '/watch?v=bdjQI-OBGk8',
#   'https://i.ytimg.com/vi/bdjQI-OBGk8/hqdefault.jpg'],
#  ['Master Data Science Concepts: Data Bricks in 60 Seconds | Data Science Crash Course | GeeksforGeeks',
#   '1K views',
#   '10 months ago',
#   '/watch?v=d1Pn06Rc9QE',
#   'https://i.ytimg.com/vi/d1Pn06Rc9QE/hqdefault.jpg'],
#  ['Master Data Science Concepts: Apache Beam in 60 Seconds | Data Science Crash Course | GeeksforGeeks',
#   '1K views',
#   '10 months ago',
#   '/watch?v=PjSA0Ru7_rI',
#   'https://i.ytimg.com/vi/PjSA0Ru7_rI/hqdefault.jpg'],
#  ['Master Data Science Concepts: Data Lake in 60 Seconds | Data Science Crash Course | GeeksforGeeks',
#   '2.2K views',
#   '10 months ago',
#   '/watch?v=KGD-T3bhFEA',
#   'https://i.ytimg.com/vi/KGD-T3bhFEA/hqdefault.jpg'],
#  ['Choosing the Right Cloud Provider | AWS vs Azure vs GCP | GeeksforGeeks',
#   '7K views',
#   '10 months ago',
#   '/watch?v=YbPnhezNaUE',
#   'https://i.ytimg.com/vi/YbPnhezNaUE/hqdefault.jpg'],
#  ['A Journey from NOKIA to PAYPAL | Ft. Palak Awasthi | GeeksforGeeks',
#   '3.2K views',
#   '10 months ago',
#   '/watch?v=6UUTPA0l748',
#   'https://i.ytimg.com/vi/6UUTPA0l748/hqdefault.jpg'],
#  ['Make Best Team For ICC Cricket World 2023 | Practice Problem | GeeksforGeeks',
#   '478 views',
#   '10 months ago',
#   '/watch?v=ItY3minkI3o',
#   'https://i.ytimg.com/vi/ItY3minkI3o/hqdefault.jpg'],
#  ['Interview Strategies for Freshers | GeeksforGeeks',
#   '5.7K views',
#   '10 months ago',
#   '/watch?v=tmg6d3T_T6Q',
#   'https://i.ytimg.com/vi/tmg6d3T_T6Q/hqdefault.jpg'],
#  ['🏆 GeeksforGeeks Hack-A-Thon: World-cup-Wizard Edition 🌟',
#   '379 views',
#   '10 months ago',
#   '/watch?v=2mW7tclj6mc',
#   'https://i.ytimg.com/vi/2mW7tclj6mc/hqdefault.jpg'],
#  ['Ace your DevOps interview | GeeksforGeeks',
#   '109K views',
#   '11 months ago',
#   '/watch?v=I-J28pjrTc8',
#   'https://i.ytimg.com/vi/I-J28pjrTc8/hqdefault.jpg'],
#  ['How to Get Free Google Cloud Qwiklabs Credits | Google Cloud Bootcamp | GeeksforGeeks',
#   '11K views',
#   '11 months ago',
#   '/watch?v=lf-eQH28eAw',
#   'https://i.ytimg.com/vi/lf-eQH28eAw/hqdefault.jpg'],
#  ['GeeksforGeeks Community – Connect, Ask, Learn & Grow with Tech Geeks',
#   '876 views',
#   '11 months ago',
#   '/watch?v=dMX0Bel8V94',
#   'https://i.ytimg.com/vi/dMX0Bel8V94/hqdefault.jpg'],
#  ['Become a SDET Expert with GeeksforGeeks',
#   '54K views',
#   '11 months ago',
#   '/watch?v=PLxzWN08w54',
#   'https://i.ytimg.com/vi/PLxzWN08w54/hqdefault.jpg'],
#  ["Geeks Premier League 2023 | India's Biggest Content Writing Event | GeeksforGeeks",
#   '1.8K views',
#   '11 months ago',
#   '/watch?v=e0DLnBRZRj0',
#   'https://i.ytimg.com/vi/PLxzWN08w54/hqdefault.jpg'],
#  ["Happy Engineer's Day To You All!",
#   '2.1K views',
#   '11 months ago',
#   '/watch?v=g4M-zfzsqBg',
#   'https://i.ytimg.com/vi/PLxzWN08w54/hqdefault.jpg'],
#  ['Decoding the Modern Job Landscape | An HR Perspective | GeeksforGeeks',
#   '826 views',
#   '1 year ago',
#   '/watch?v=w3ucO_5NHCU',
#   'https://i.ytimg.com/vi/PLxzWN08w54/hqdefault.jpg'],
#  ['Unlock GATE 2024 | GeeksforGeeks',
#   '22K views',
#   '1 year ago',
#   '/watch?v=4TVPoMDU0Ts',
#   'https://i.ytimg.com/vi/PLxzWN08w54/hqdefault.jpg'],
#  ['We Stole This For You',
#   '7.3K views',
#   '1 year ago',
#   '/watch?v=eVV0MO_IBnw',
#   'https://i.ytimg.com/vi/PLxzWN08w54/hqdefault.jpg'],
#  ['Career Advancement Test For EWS & PWD Candidates | Student Grant of INR 10 Lakh | GeeksforGeeks',
#   '6.1K views',
#   '1 year ago',
#   '/watch?v=DpCJ74xg93E',
#   'https://i.ytimg.com/vi/PLxzWN08w54/hqdefault.jpg'],
#  ['GfG Mobile App | Android & iOS | Download for Free',
#   '11K views',
#   '1 year ago',
#   '/watch?v=Rsh8xd3aIqw',
#   'https://i.ytimg.com/vi/Rsh8xd3aIqw/hqdefault.jpg'],
#  ["🔒 Securing Your Data in the Cloud: GCP's Top SECURITY Features | GeesforGeeks",
#   '460 views',
#   '1 year ago',
#   '/watch?v=rwLBsyQ4rO8',
#   'https://i.ytimg.com/vi/rwLBsyQ4rO8/hqdefault.jpg'],
#  ['GATE CSE Offline Classes | GATE 2024 Crash Course | Delhi NCR | GeeksforGeeks',
#   '18K views',
#   '1 year ago',
#   '/watch?v=a9xiYYqbaHg',
#   'https://i.ytimg.com/vi/a9xiYYqbaHg/hqdefault.jpg'],
#  ['How to Build a To-Do Application in Flutter | GeeksforGeeks',
#   '1.1K views',
#   '1 year ago',
#   '/watch?v=fNuURHd7POk',
#   'https://i.ytimg.com/vi/fNuURHd7POk/hqdefault.jpg'],
#  ['How to Use Google Sign-in With Firebase in Flutter | GeeksforGeeks',
#   '9.5K views',
#   '1 year ago',
#   '/watch?v=MRb_2Kg0nRI',
#   'https://i.ytimg.com/vi/MRb_2Kg0nRI/hqdefault.jpg'],
#  ['Machine Learning on GCP | Harnessing the Power of AI | GeeksforGeeks',
#   '550 views',
#   '1 year ago',
#   '/watch?v=KSTX28pUSeI',
#   'https://i.ytimg.com/vi/KSTX28pUSeI/hqdefault.jpg'],
#  ['GRAPH Data Structure | What is Graph? | DSA Course | GeeksforGeeks',
#   '22K views',
#   '1 year ago',
#   '/watch?v=gTsoyORhqkg',
#   'https://i.ytimg.com/vi/gTsoyORhqkg/hqdefault.jpg'],
#  ['Handling Missing Values | Machine Learning | GeeksforGeeks',
#   '1.1K views',
#   '1 year ago',
#   '/watch?v=yFJ2_phRslY',
#   'https://i.ytimg.com/vi/yFJ2_phRslY/hqdefault.jpg'],
#  ['Security Risks of Cloud Computing | GeeksforGeeks',
#   '3.4K views',
#   '1 year ago',
#   '/watch?v=6lxKkdyvS6M',
#   'https://i.ytimg.com/vi/6lxKkdyvS6M/hqdefault.jpg'],
#  ['DSA Classroom Program with Placement Assistance | Now in Noida & Gurugram | GeeksforGeeks',
#   '149K views',
#   '1 year ago',
#   '/watch?v=ACZoeLwm_fE',
#   'https://i.ytimg.com/vi/ACZoeLwm_fE/hqdefault.jpg'],
#  ['Free Cloud Bootcamp Sponsored by Google for Developers | GeeksforGeeks',
#   '2.3K views',
#   '1 year ago',
#   '/watch?v=uXpOqQEw7Pc',
#   'https://i.ytimg.com/vi/uXpOqQEw7Pc/hqdefault.jpg'],
#  ['All Your Queries Answered | DSA to Development Program | GeeksforGeeks',
#   '3.1K views',
#   '1 year ago',
#   '/watch?v=kHBzDvj3D2U',
#   'https://i.ytimg.com/vi/kHBzDvj3D2U/hqdefault.jpg'],
#  ['10 TIPS and TRICKS to Crack Internships and Placements | GeeksforGeeks',
#   '896 views',
#   '1 year ago',
#   '/watch?v=2QDMIZGeIC4',
#   'https://i.ytimg.com/vi/2QDMIZGeIC4/hqdefault.jpg'],
#  ['Complete School Guide for CBSE | Free Resources For School Students | GeeksforGeeks',
#   '669 views',
#   '1 year ago',
#   '/watch?v=1ECMlxC6jbs',
#   'https://i.ytimg.com/vi/1ECMlxC6jbs/hqdefault.jpg'],
#  ['Master System Design | GeeksforGeeks',
#   '87K views',
#   '1 year ago',
#   '/watch?v=vjWLZYeqiN8',
#   'https://i.ytimg.com/vi/vjWLZYeqiN8/hqdefault.jpg'],
#  ['Unraveling the Geek-a-thon: The What, How, and Why | Geek-A-Thon | GeeksforGeeks',
#   '565 views',
#   '1 year ago',
#   '/watch?v=6e0v_NhsFMQ',
#   'https://i.ytimg.com/vi/6e0v_NhsFMQ/hqdefault.jpg'],
#  ['Data Analysis Masterclass | Geek-A-Thon | GeeksforGeeks',
#   '999 views',
#   '1 year ago',
#   '/watch?v=-7Emxpn8DXc',
#   'https://i.ytimg.com/vi/-7Emxpn8DXc/hqdefault.jpg'],
#  ['GeeksforGeeks Offline Classroom Program | Now Open In Noida & Gurgaon',
#   '43K views',
#   '1 year ago',
#   '/watch?v=2bPiFkt3Nmg',
#   'https://i.ytimg.com/vi/2bPiFkt3Nmg/hqdefault.jpg'],
#  ['Kickstart your DevOps Career | GeeksforGeeks',
#   '137K views',
#   '1 year ago',
#   '/watch?v=8gwwlpBwr_s',
#   'https://i.ytimg.com/vi/8gwwlpBwr_s/hqdefault.jpg'],
#  ['First Ever KBC at our Offline Classes | GeeksforGeeks',
#   '767 views',
#   '1 year ago',
#   '/watch?v=chYg2EAKW2A',
#   'https://i.ytimg.com/vi/chYg2EAKW2A/hqdefault.jpg'],
#  ['Mega Job-a-thon for Working Professionals | 21st July | GeeksforGeeks',
#   '1.3K views',
#   '1 year ago',
#   '/watch?v=CyOh-WDfUvs',
#   'https://i.ytimg.com/vi/CyOh-WDfUvs/hqdefault.jpg'],
#  ['Explore GeeksforGeeks Hiring Solutions | For Top Tech Companies | Innovative Hiring Solutions',
#   '646 views',
#   '1 year ago',
#   '/watch?v=GDeoPHRqb5w',
#   'https://i.ytimg.com/vi/GDeoPHRqb5w/hqdefault.jpg'],
#  ['Geek-O-Lympics 2023 | GeeksforGeeks',
#   '3.5K views',
#   '1 year ago',
#   '/watch?v=hLqJiIu6LzY',
#   'https://i.ytimg.com/vi/hLqJiIu6LzY/hqdefault.jpg'],
#  ['Web 3.0 Explained | GeeksforGeeks',
#   '2K views',
#   '1 year ago',
#   '/watch?v=zEPRJMk3p90',
#   'https://i.ytimg.com/vi/zEPRJMk3p90/hqdefault.jpg'],
#  ['Geek-O-Lympics 2023 | 1st - 31st July | GeeksforGeeks',
#   '1.2K views',
#   '1 year ago',
#   '/watch?v=GSqepfZLKU0',
#   'https://i.ytimg.com/vi/zEPRJMk3p90/hqdefault.jpg'],
#  ['What Is Web Scraping & What It Is Used For | How To Use Web Scraping | GeeksforGeeks',
#   '1.3K views',
#   '1 year ago',
#   '/watch?v=MK15a0ipg-E',
#   'https://i.ytimg.com/vi/zEPRJMk3p90/hqdefault.jpg'],
#  ['Mega Job-A-Thon | Hire Top Talent for Your Company | GeeksforGeeks',
#   '1.4K views',
#   '1 year ago',
#   '/watch?v=cWPqVVobUuA',
#   'https://i.ytimg.com/vi/zEPRJMk3p90/hqdefault.jpg'],
#  ['DSA To Development: A Complete Coding Guide | Complete Coding Program By GeeksforGeeks',
#   '175K views',
#   '1 year ago',
#   '/watch?v=phr8lXH2Ee0',
#   'https://i.ytimg.com/vi/zEPRJMk3p90/hqdefault.jpg'],
#  ['WHAT IS QUEUE? | Queue Data Structures | DSA Course | GeeksforGeeks',
#   '8.5K views',
#   '1 year ago',
#   '/watch?v=ypJwoz_SXTo',
#   'https://i.ytimg.com/vi/zEPRJMk3p90/hqdefault.jpg'],
#  ['QUEUE PRACTICE PROBLEMS | Queue Interview Questions | DSA Problems | GeeksforGeeks',
#   '4.2K views',
#   '1 year ago',
#   '/watch?v=KG4dbF5xRig',
#   'https://i.ytimg.com/vi/zEPRJMk3p90/hqdefault.jpg'],
#  ['Free Summer Offline Classes on Python Programing | For Students Aged 14-21 | GeeksforGeeks',
#   '107K views',
#   '1 year ago',
#   '/watch?v=OOLXHwZzHfM',
#   'https://i.ytimg.com/vi/OOLXHwZzHfM/hqdefault.jpg'],
#  ['Python Libraries | Data Science | GeeksforGeeks',
#   '2.7K views',
#   '1 year ago',
#   '/watch?v=nDa75spDmeE',
#   'https://i.ytimg.com/vi/nDa75spDmeE/hqdefault.jpg'],
#  ['ITR Filing Made Simple | Documents require to file ITR | GeeksforGeeks',
#   '999 views',
#   '1 year ago',
#   '/watch?v=SWa-tsbaIpg',
#   'https://i.ytimg.com/vi/SWa-tsbaIpg/hqdefault.jpg'],
#  ['Full Stack Development | LIVE Classes | GeeksforGeeks',
#   '214K views',
#   '1 year ago',
#   '/watch?v=cBfC9HLR9Qk',
#   'https://i.ytimg.com/vi/cBfC9HLR9Qk/hqdefault.jpg'],
#  ['GeeksforGeeks Classroom Program in NCR',
#   '2.6K views',
#   '1 year ago',
#   '/watch?v=uEhnTpHY26o',
#   'https://i.ytimg.com/vi/uEhnTpHY26o/hqdefault.jpg'],
#  ['WHAT IS ARRAY? | Array Data Structures | DSA Course | GeeksforGeeks',
#   '41K views',
#   '1 year ago',
#   '/watch?v=3_x_Fb31NLE',
#   'https://i.ytimg.com/vi/3_x_Fb31NLE/hqdefault.jpg'],
#  ['ARRAY PRACTICE PROBLEMS | Must do Array Questions | DSA Problems | GeeksforGeeks',
#   '26K views',
#   '1 year ago',
#   '/watch?v=J7EhXvnixRM',
#   'https://i.ytimg.com/vi/J7EhXvnixRM/hqdefault.jpg'],
#  ['Gate 2024: Prepare for Success! | GATE CSE 2024 | GeeksforGeeks',
#   '63K views',
#   '1 year ago',
#   '/watch?v=G-3vZKPEtKw',
#   'https://i.ytimg.com/vi/G-3vZKPEtKw/hqdefault.jpg'],
#  ['Get Started with CP | Competitive Programming Tips | GeeksforGeeks',
#   '3.3K views',
#   '1 year ago',
#   '/watch?v=FCEj-mreXvI',
#   'https://i.ytimg.com/vi/FCEj-mreXvI/hqdefault.jpg'],
#  ['React VS Angular VS Vue | GeeksforGeeks',
#   '24K views',
#   '1 year ago',
#   '/watch?v=sA2vgFR-fZc',
#   'https://i.ytimg.com/vi/sA2vgFR-fZc/hqdefault.jpg'],
#  ['GeeksforGeeks Classroom Program | Now in Noida and Gurugram!',
#   '269K views',
#   '1 year ago',
#   '/watch?v=16D2cuRy5JY',
#   'https://i.ytimg.com/vi/16D2cuRy5JY/hqdefault.jpg'],
#  ['Transformers in NLP | GeeksforGeeks',
#   '19K views',
#   '1 year ago',
#   '/watch?v=-eqjV5dwb9Q',
#   'https://i.ytimg.com/vi/-eqjV5dwb9Q/hqdefault.jpg'],
#  ["Jobs that AI can't replace | GeeksforGeeks",
#   '4.5K views',
#   '1 year ago',
#   '/watch?v=uY05MFnSMwU',
#   'https://i.ytimg.com/vi/uY05MFnSMwU/hqdefault.jpg'],
#  ['Job Fair for Students | Till 25th May Only | GeeksforGeeks',
#   '83K views',
#   '1 year ago',
#   '/watch?v=1GEegOb3fHE',
#   'https://i.ytimg.com/vi/1GEegOb3fHE/hqdefault.jpg'],
#  ['Flutter: "Pros and Cons" | GeeksforGeeks',
#   '7.9K views',
#   '1 year ago',
#   '/watch?v=0gnaXUiSELY',
#   'https://i.ytimg.com/vi/0gnaXUiSELY/hqdefault.jpg'],
#  ['Hire Best Talent with GeeksforGeeks',
#   '14K views',
#   '1 year ago',
#   '/watch?v=xifGlf39ahQ',
#   'https://i.ytimg.com/vi/xifGlf39ahQ/hqdefault.jpg'],
#  ['Tech Jobs without Degree | GeeksforGeeks',
#   '2.1K views',
#   '1 year ago',
#   '/watch?v=5jHvfzt8Ors',
#   'https://i.ytimg.com/vi/5jHvfzt8Ors/hqdefault.jpg'],
#  ['Start your writing Journey | Geek Author Badges | GeeksforGeeks',
#   '1.6K views',
#   '1 year ago',
#   '/watch?v=ISPOKldx90E',
#   'https://i.ytimg.com/vi/ISPOKldx90E/hqdefault.jpg'],
#  ['Presenting: GeeksforGeeks Author Badges | Honoring the Writer in You!',
#   '1.2K views',
#   '1 year ago',
#   '/watch?v=kW9BohViP04',
#   'https://i.ytimg.com/vi/kW9BohViP04/hqdefault.jpg'],
#  ['Create Your Own Apps Today | GeeksforGeeks',
#   '35K views',
#   '1 year ago',
#   '/watch?v=LycNCWC3g18',
#   'https://i.ytimg.com/vi/LycNCWC3g18/hqdefault.jpg'],
#  ['Top 10 DSA Topics | Master these To Ace In Your Career | GeeksforGeeks',
#   '2.8K views',
#   '1 year ago',
#   '/watch?v=t8aN8nczZlA',
#   'https://i.ytimg.com/vi/t8aN8nczZlA/hqdefault.jpg'],
#  ['Ernie vs ChatGPT | GeeksforGeeks',
#   '1.7K views',
#   '1 year ago',
#   '/watch?v=iM-EpJHn59Q',
#   'https://i.ytimg.com/vi/iM-EpJHn59Q/hqdefault.jpg'],
#  ['Rule the Coding World with Geek Summer Carnival | GeeksforGeeks',
#   '25K views',
#   '1 year ago',
#   '/watch?v=zLj3Qb9T2Q4',
#   'https://i.ytimg.com/vi/zLj3Qb9T2Q4/hqdefault.jpg'],
#  ['How to become a Full Stack Developer | GeeksforGeeks',
#   '5.6K views',
#   '1 year ago',
#   '/watch?v=uSx5XsCkX3c',
#   'https://i.ytimg.com/vi/uSx5XsCkX3c/hqdefault.jpg'],
#  ['Office Video Leaked 😰🤯',
#   '6K views',
#   '1 year ago',
#   '/watch?v=i_HlQl7Tg9Q',
#   'https://i.ytimg.com/vi/uSx5XsCkX3c/hqdefault.jpg'],
# ...
#   '762 views',
#   '5 years ago',
#   '/watch?v=eWD1k2zSt9g',
#   'https://i.ytimg.com/vi/0lHrGAGbldo/hqdefault.jpg'],
#  ['Go Programming Language | Part 7 | Multiple Return Values and Go Formatting Tools | GeeksforGeeks',
#   '575 views',
#   '5 years ago',
#   '/watch?v=GPs3zyDr4pY',
#   'https://i.ytimg.com/vi/0lHrGAGbldo/hqdefault.jpg'],
#  ['Object Oriented Design and Design Patterns | GeeksforGeeks',
#   '14K views',
#   '5 years ago',
#   '/watch?v=AopCPq2cZlA',
#   'https://i.ytimg.com/vi/0lHrGAGbldo/hqdefault.jpg'],
#  ['Synchronization | GeeksforGeeks',
#   '37K views',
#   '5 years ago',
#   '/watch?v=IIgHG_YHXPE',
#   'https://i.ytimg.com/vi/0lHrGAGbldo/hqdefault.jpg'],
#  ['5. For Loop in Java (Core Java) | GeeksforGeeks',
#   '4.3K views',
#   '5 years ago',
#   '/watch?v=JkSQ8KtOA14',
#   'https://i.ytimg.com/vi/0lHrGAGbldo/hqdefault.jpg'],
#  ['4. Do While Loop in Java | GeeksforGeeks',
#   '4.8K views',
#   '5 years ago',
#   '/watch?v=8AmQkU9AhpU',
#   'https://i.ytimg.com/vi/0lHrGAGbldo/hqdefault.jpg'],
#  ['3. While Loop in Java (Core Java)| GeeksforGeeks',
#   '8.6K views',
#   '5 years ago',
#   '/watch?v=xBJ44A1FCTE',
#   'https://i.ytimg.com/vi/0lHrGAGbldo/hqdefault.jpg'],
#  ['Race Condition (Java) | GeeksforGeeks',
#   '21K views',
#   '5 years ago',
#   '/watch?v=P9OWSLpLfwo',
#   'https://i.ytimg.com/vi/0lHrGAGbldo/hqdefault.jpg'],
#  ['2. Keywords in Java (Core Java) | GeeksforGeeks',
#   '9.3K views',
#   '5 years ago',
#   '/watch?v=yLhVhi4rxsA',
#   'https://i.ytimg.com/vi/0lHrGAGbldo/hqdefault.jpg'],
#  ['1. Identifiers and Tokens in Java (Core Java) | GeeksforGeeks',
#   '20K views',
#   '5 years ago',
#   '/watch?v=W_6zSjdwR7c',
#   'https://i.ytimg.com/vi/0lHrGAGbldo/hqdefault.jpg'],
#  ['Use of realloc | GeeksforGeeks',
#   '3.4K views',
#   '5 years ago',
#   '/watch?v=Fp7p5ax1oss',
#   'https://i.ytimg.com/vi/0lHrGAGbldo/hqdefault.jpg'],
#  ['Placement 100 | GeeksforGeeks',
#   '182K views',
#   '5 years ago',
#   '/watch?v=B-niwoYEDys',
#   'https://i.ytimg.com/vi/0lHrGAGbldo/hqdefault.jpg'],
#  ['Placement 100 | Teaser 2 | GeeksforGeeks',
#   '3K views',
#   '5 years ago',
#   '/watch?v=SvR2BPLcgAI',
#   'https://i.ytimg.com/vi/0lHrGAGbldo/hqdefault.jpg'],
#  ['Understanding “register” keyword in C | GeeksforGeeks',
#   '9.1K views',
#   '5 years ago',
#   '/watch?v=-fOCN-l_Jb8',
#   'https://i.ytimg.com/vi/0lHrGAGbldo/hqdefault.jpg'],
#  ['Placement 100 | Teaser | GeeksforGeeks',
#   '35K views',
#   '5 years ago',
#   '/watch?v=Dna1LIaC3C4',
#   'https://i.ytimg.com/vi/0lHrGAGbldo/hqdefault.jpg'],
#  ['Storage classes (2) | GeeksforGeeks',
#   '5.8K views',
#   '5 years ago',
#   '/watch?v=g6g4KgUuq4s',
#   'https://i.ytimg.com/vi/g6g4KgUuq4s/hqdefault.jpg'],
#  ['Storage classes | GeeksforGeeks',
#   '20K views',
#   '5 years ago',
#   '/watch?v=VcQWlALilak',
#   'https://i.ytimg.com/vi/VcQWlALilak/hqdefault.jpg'],
#  ['What is evaluation order of function parameters in C? | GeeksforGeeks',
#   '2.1K views',
#   '5 years ago',
#   '/watch?v=wmKsc5p4mu4',
#   'https://i.ytimg.com/vi/wmKsc5p4mu4/hqdefault.jpg'],
#  ['Thread Sleep | GeeksforGeeks',
#   '16K views',
#   '5 years ago',
#   '/watch?v=PUWqBqHWcJs',
#   'https://i.ytimg.com/vi/PUWqBqHWcJs/hqdefault.jpg'],
#  ['Calloc vs malloc | GeeksforGeeks',
#   '19K views',
#   '5 years ago',
#   '/watch?v=NynaUiV7keU',
#   'https://i.ytimg.com/vi/NynaUiV7keU/hqdefault.jpg'],
#  ['Struct hack | GeeksforGeeks',
#   '1.9K views',
#   '5 years ago',
#   '/watch?v=6KGl16FfjEU',
#   'https://i.ytimg.com/vi/6KGl16FfjEU/hqdefault.jpg'],
#  ['Classroom Program by GeeksforGeeks',
#   '12K views',
#   '5 years ago',
#   '/watch?v=CHpRRO2b5aU',
#   'https://i.ytimg.com/vi/CHpRRO2b5aU/hqdefault.jpg'],
#  ['How to deallocate memory without using free() in C? | GeeksforGeeks',
#   '3.1K views',
#   '5 years ago',
#   '/watch?v=3fABLWAJuZE',
#   'https://i.ytimg.com/vi/3fABLWAJuZE/hqdefault.jpg'],
#  ['Memory layout of C programs | GeeksforGeeks',
#   '61K views',
#   '5 years ago',
#   '/watch?v=kpWG423uQIw',
#   'https://i.ytimg.com/vi/kpWG423uQIw/hqdefault.jpg'],
#  ['Structure Member Alighnment and Padding (Part 4) | GeeksforGeeks',
#   '2.9K views',
#   '5 years ago',
#   '/watch?v=3u47OkRsxjY',
#   'https://i.ytimg.com/vi/3u47OkRsxjY/hqdefault.jpg'],
#  ['Structure Member Alighnment and Padding (Part 3) | GeeksforGeeks',
#   '3.9K views',
#   '5 years ago',
#   '/watch?v=oR-m18-OkPc',
#   'https://i.ytimg.com/vi/oR-m18-OkPc/hqdefault.jpg'],
#  ['Structure Member Alighnment and Padding (Part 2) | GeeksforGeeks',
#   '4.4K views',
#   '5 years ago',
#   '/watch?v=pvdEIE858mU',
#   'https://i.ytimg.com/vi/pvdEIE858mU/hqdefault.jpg'],
#  ['Structure Member Alighnment and Padding (Part 1) | GeeksforGeeks',
#   '14K views',
#   '5 years ago',
#   '/watch?v=RR57zUBbwEM',
#   'https://i.ytimg.com/vi/RR57zUBbwEM/hqdefault.jpg'],
#  ['Reverse a Linked List in groups of given size | Set 1 | GeeksforGeeks',
#   '19K views',
#   '5 years ago',
#   '/watch?v=9V_1yk_Y7n0',
#   'https://i.ytimg.com/vi/9V_1yk_Y7n0/hqdefault.jpg'],
#  ['Greedy Algorithm for Egyptian Fraction | GeeksforGeeks',
#   '8K views',
#   '5 years ago',
#   '/watch?v=8icU9XMEwjs',
#   'https://i.ytimg.com/vi/8icU9XMEwjs/hqdefault.jpg'],
#  ['Maximum length of rod for Q-th person | GeeksforGeeks',
#   '688 views',
#   '5 years ago',
#   '/watch?v=NpytzZfg_h8',
#   'https://i.ytimg.com/vi/8icU9XMEwjs/hqdefault.jpg'],
#  ['SORTING A QUEUE Without Extra Space | Queue Practice Questions | GeeksforGeeks',
#   '12K views',
#   '5 years ago',
#   '/watch?v=OcQyfkpA0YY',
#   'https://i.ytimg.com/vi/8icU9XMEwjs/hqdefault.jpg'],
#  ['An Interesting Method to generate binary numbers | GeeksforGeeks',
#   '11K views',
#   '5 years ago',
#   '/watch?v=LeMfdGyN-F0',
#   'https://i.ytimg.com/vi/8icU9XMEwjs/hqdefault.jpg'],
#  ['How does free() know the size of memory to be deallocated? (C Programming) | GeeksforGeeks',
#   '4.5K views',
#   '5 years ago',
#   '/watch?v=egUvdR3ejKU',
#   'https://i.ytimg.com/vi/8icU9XMEwjs/hqdefault.jpg'],
#  ['Go Programming Language ( Go Part : An Overview) | GeeksforGeeks',
#   '926 views',
#   '5 years ago',
#   '/watch?v=8g4uzx_ShHQ',
#   'https://i.ytimg.com/vi/8icU9XMEwjs/hqdefault.jpg'],
#  ['A look of DSA Self Paced | GeeksforGeeks',
#   '47K views',
#   '5 years ago',
#   '/watch?v=X6ewqgkkNbA',
#   'https://i.ytimg.com/vi/8icU9XMEwjs/hqdefault.jpg'],
#  ['Memory leak | GeeksforGeeks',
#   '7.2K views',
#   '5 years ago',
#   '/watch?v=ZrkpRX1TLOc',
#   'https://i.ytimg.com/vi/8icU9XMEwjs/hqdefault.jpg'],
#  ['Reverse a Linked List in groups of given size | Set 2 | GeeksforGeeks',
#   '5.2K views',
#   '5 years ago',
#   '/watch?v=aF9PGkR0dWU',
#   'https://i.ytimg.com/vi/8icU9XMEwjs/hqdefault.jpg'],
#  ['DSA Online - Basic to Advanced Course (DSA 3) | GeeksforGeeks',
#   '46K views',
#   '5 years ago',
#   '/watch?v=YNk1YSqGiVU',
#   'https://i.ytimg.com/vi/8icU9XMEwjs/hqdefault.jpg'],
#  ['Functions In Go Programming Language | GeeksforGeeks',
#   '429 views',
#   '5 years ago',
#   '/watch?v=BmAncjcPAmk',
#   'https://i.ytimg.com/vi/8icU9XMEwjs/hqdefault.jpg'],
#  ['DSA Online (Binary Search) | GeeksforGeeks',
#   '38K views',
#   '5 years ago',
#   '/watch?v=p9FZlPxukVI',
#   'https://i.ytimg.com/vi/8icU9XMEwjs/hqdefault.jpg'],
#  ['Thread Naming (Java) | GeeksforGeeks',
#   '4.1K views',
#   '5 years ago',
#   '/watch?v=DaslnWaEq3g',
#   'https://i.ytimg.com/vi/8icU9XMEwjs/hqdefault.jpg'],
#  ['Thread.yield() | GeeksforGeeks',
#   '12K views',
#   '5 years ago',
#   '/watch?v=_c784Dgj39o',
#   'https://i.ytimg.com/vi/8icU9XMEwjs/hqdefault.jpg'],
#  ['Structures in C | GeeksforGeeks',
#   '4.7K views',
#   '5 years ago',
#   '/watch?v=Rd28GUWEeEs',
#   'https://i.ytimg.com/vi/8icU9XMEwjs/hqdefault.jpg'],
#  ['Iterative O(log) function for pow(x,y) | GeeksforGeeks',
#   '3.1K views',
#   '5 years ago',
#   '/watch?v=VJ7mkRu3sNc',
#   'https://i.ytimg.com/vi/8icU9XMEwjs/hqdefault.jpg'],
#  ['Calculate power (x,y) using recursion | GeeksforGeeks',
#   '27K views',
#   '5 years ago',
#   '/watch?v=rOs6t7FS4xk',
#   'https://i.ytimg.com/vi/rOs6t7FS4xk/hqdefault.jpg'],
#  ['Operations on struct variables in C | GeeksforGeeks',
#   '1.9K views',
#   '5 years ago',
#   '/watch?v=KHDnKkSediE',
#   'https://i.ytimg.com/vi/KHDnKkSediE/hqdefault.jpg'],
#  ['Go Programming Language | Variables In GO | GeeksforGeeks',
#   '364 views',
#   '5 years ago',
#   '/watch?v=vpjRF0FHRFk',
#   'https://i.ytimg.com/vi/vpjRF0FHRFk/hqdefault.jpg'],
#  ['Types in Go (Go Programming)| GeeksforGeeks',
#   '600 views',
#   '5 years ago',
#   '/watch?v=vhysIDumk2U',
#   'https://i.ytimg.com/vi/vhysIDumk2U/hqdefault.jpg'],
#  ['Pointer vs Array (C Programming) | GeeksforGeeks',
#   '6.4K views',
#   '5 years ago',
#   '/watch?v=8dUZpFKvKG0',
#   'https://i.ytimg.com/vi/8dUZpFKvKG0/hqdefault.jpg'],
#  ['restrict keyword in C (C Programming) | GeeksforGeeks',
#   '7.3K views',
#   '5 years ago',
#   '/watch?v=ohXjzvcX6Ic',
#   'https://i.ytimg.com/vi/ohXjzvcX6Ic/hqdefault.jpg'],
#  ['Void Pointer in C | GeeksforGeeks',
#   '12K views',
#   '5 years ago',
#   '/watch?v=9dkVR-qunnw',
#   'https://i.ytimg.com/vi/9dkVR-qunnw/hqdefault.jpg'],
#  ['Thread Scheduler & Thread Priority | GeeksforGeeks',
#   '21K views',
#   '5 years ago',
#   '/watch?v=7q22vVYKpnQ',
#   'https://i.ytimg.com/vi/7q22vVYKpnQ/hqdefault.jpg'],
#  ['Functions that are executed before and after main() in C | GeeksforGeeks',
#   '3.4K views',
#   '5 years ago',
#   '/watch?v=ETF6u22NjOI',
#   'https://i.ytimg.com/vi/ETF6u22NjOI/hqdefault.jpg'],
#  ['Functions in C / C++ | GeeksforGeeks',
#   '13K views',
#   '5 years ago',
#   '/watch?v=dfpCveipYRQ',
#   'https://i.ytimg.com/vi/dfpCveipYRQ/hqdefault.jpg'],
#  ['Find nth fibonacci no. using recursive technique. | GeeksforGeeks',
#   '62K views',
#   '5 years ago',
#   '/watch?v=4GMh0MfCiqE',
#   'https://i.ytimg.com/vi/4GMh0MfCiqE/hqdefault.jpg'],
#  ['Recursive O(logy) function for pow(x,y) | GeeksforGeeks',
#   '4.7K views',
#   '5 years ago',
#   '/watch?v=2a_Snu8qjko',
#   'https://i.ytimg.com/vi/2a_Snu8qjko/hqdefault.jpg'],
#  ['DSA Online Course | GeeksforGeeks',
#   '69K views',
#   '5 years ago',
#   '/watch?v=BnJWi0E3Mv0',
#   'https://i.ytimg.com/vi/BnJWi0E3Mv0/hqdefault.jpg'],
#  ['Lets Create Threads (JAVA) | GeeksforGeeks',
#   '12K views',
#   '5 years ago',
#   '/watch?v=kviGixevLNA',
#   'https://i.ytimg.com/vi/kviGixevLNA/hqdefault.jpg'],
#  ['Introduction to Multithreading  (JAVA) | GeeksforGeeks',
#   '47K views',
#   '5 years ago',
#   '/watch?v=J_7FtjWgoC4',
#   'https://i.ytimg.com/vi/J_7FtjWgoC4/hqdefault.jpg'],
#  ['How to declare a pointer to a function? | GeeksforGeeks',
#   '4.5K views',
#   '5 years ago',
#   '/watch?v=eEHzPJrhK7g',
#   'https://i.ytimg.com/vi/J_7FtjWgoC4/hqdefault.jpg'],
#  ['Difference between const char *p, char * const p and const char * const p | GeeksforGeeks',
#   '7.7K views',
#   '5 years ago',
#   '/watch?v=hbncWGZ8tDg',
#   'https://i.ytimg.com/vi/J_7FtjWgoC4/hqdefault.jpg'],
#  ['Digital Image Processing INTRODUCTION | GeeksforGeeks',
#   '35K views',
#   '5 years ago',
#   '/watch?v=F7NSNnd8-Ao',
#   'https://i.ytimg.com/vi/J_7FtjWgoC4/hqdefault.jpg'],
#  ['Pointer to an Array PART - 2 | GeeksforGeeks',
#   '3.4K views',
#   '5 years ago',
#   '/watch?v=xmemQ1ka3uo',
#   'https://i.ytimg.com/vi/J_7FtjWgoC4/hqdefault.jpg'],
#  ['Pointer to an Array PART - 1 | GeeksforGeeks',
#   '15K views',
#   '5 years ago',
#   '/watch?v=jYuqC9UD4GI',
#   'https://i.ytimg.com/vi/J_7FtjWgoC4/hqdefault.jpg'],
#  ['Linear Search vs Binary Search | GeeksforGeeks',
#   '45K views',
#   '5 years ago',
#   '/watch?v=qBGLYzFF1aQ',
#   'https://i.ytimg.com/vi/J_7FtjWgoC4/hqdefault.jpg'],
#  ['Downloading and Installing Go and Working with packages. | GeeksforGeeks',
#   '2.3K views',
#   '5 years ago',
#   '/watch?v=ApZiFdS6l54',
#   'https://i.ytimg.com/vi/J_7FtjWgoC4/hqdefault.jpg'],
#  ['An Uncommon representation of array elements | GeeksforGeeks',
#   '3K views',
#   '5 years ago',
#   '/watch?v=Uw_TtJQyrwk',
#   'https://i.ytimg.com/vi/J_7FtjWgoC4/hqdefault.jpg'],
#  ['Dangling, Void , Null and Wild Pointers | GeeksforGeeks',
#   '21K views',
#   '5 years ago',
#   '/watch?v=uvw5bZZT3pM',
#   'https://i.ytimg.com/vi/J_7FtjWgoC4/hqdefault.jpg'],
#  ['Downloading and Storing Packages In Go | GeeksforGeeks',
#   '307 views',
#   '5 years ago',
#   '/watch?v=oBjUUF054w8',
#   'https://i.ytimg.com/vi/J_7FtjWgoC4/hqdefault.jpg'],
#  ['Dereference, Reference | GeeksforGeeks',
#   '12K views',
#   '5 years ago',
#   '/watch?v=Sqmo6qadIDE',
#   'https://i.ytimg.com/vi/J_7FtjWgoC4/hqdefault.jpg'],
#  ['Why C treats array parameters as pointers? | GeeksforGeeks',
#   '6K views',
#   '5 years ago',
#   '/watch?v=yI3jxhfyghA',
#   'https://i.ytimg.com/vi/J_7FtjWgoC4/hqdefault.jpg'],
#  ['Linux Tutorials | tr command | GeeksforGeeks',
#   '28K views',
#   '5 years ago',
#   '/watch?v=iNWdEWWYo50',
#   'https://i.ytimg.com/vi/J_7FtjWgoC4/hqdefault.jpg'],
#  ['Linux Tutorials | uniq command | GeeksforGeeks',
#   '18K views',
#   '5 years ago',
#   '/watch?v=k2k1LaKsAWI',
#   'https://i.ytimg.com/vi/J_7FtjWgoC4/hqdefault.jpg'],
#  ['GRE Test Series | GeeksforGeeks',
#   '2.5K views',
#   '5 years ago',
#   '/watch?v=pS5Pb6uBbRE',
#   'https://i.ytimg.com/vi/J_7FtjWgoC4/hqdefault.jpg'],
#  ['Pointers in C Basic | GeeksforGeeks',
#   '52K views',
#   '5 years ago',
#   '/watch?v=qcWQ1AmmNWI',
#   'https://i.ytimg.com/vi/qcWQ1AmmNWI/hqdefault.jpg'],
#  ['Double Pointer (Pointer to Pointer) in C | GeeksforGeeks',
#   '65K views',
#   '5 years ago',
#   '/watch?v=ahKfY1EsWd8',
#   'https://i.ytimg.com/vi/ahKfY1EsWd8/hqdefault.jpg'],
#  ['Linux Tutorials | sort command  GeeksforGeeks',
#   '43K views',
#   '5 years ago',
#   '/watch?v=fEx5rnbDKO4',
#   'https://i.ytimg.com/vi/fEx5rnbDKO4/hqdefault.jpg'],
#  ['Linux Tutorials | paste command | GeeksforGeeks',
#   '15K views',
#   '5 years ago',
#   '/watch?v=ilV6dcTJzzE',
#   'https://i.ytimg.com/vi/ilV6dcTJzzE/hqdefault.jpg'],
#  ['Linux Tutorials | cut command | Splitting a file vertically | GeeksforGeeks',
#   '50K views',
#   '5 years ago',
#   '/watch?v=eHGCxEVlHd0',
#   'https://i.ytimg.com/vi/eHGCxEVlHd0/hqdefault.jpg'],
#  ['Linux Tutorials | Print line between M and N lines head and tail combined | GeeksforGeeks',
#   '4.5K views',
#   '5 years ago',
#   '/watch?v=tMXF-YKyP0w',
#   'https://i.ytimg.com/vi/tMXF-YKyP0w/hqdefault.jpg'],
#  ['Linux Tutorials | tail command | GeeksforGeeks',
#   '17K views',
#   '5 years ago',
#   '/watch?v=1pD28tFgAb8',
#   'https://i.ytimg.com/vi/1pD28tFgAb8/hqdefault.jpg'],
#  ['System Design | GeeksforGeeks',
#   '4.4K views',
#   '5 years ago',
#   '/watch?v=b-P-auApWEk',
#   'https://i.ytimg.com/vi/b-P-auApWEk/hqdefault.jpg'],
#  ['Linux Tutorials | head command | GeeksforGeeks',
#   '13K views',
#   '5 years ago',
#   '/watch?v=ZZACz-filWU',
#   'https://i.ytimg.com/vi/ZZACz-filWU/hqdefault.jpg'],
#  ['Mr. Sandeep Jain explaining Array Traversal Concept | GeeksforGeeks',
#   '7.7K views',
#   '5 years ago',
#   '/watch?v=vgq1gDrXlsk',
#   'https://i.ytimg.com/vi/vgq1gDrXlsk/hqdefault.jpg'],
#  ['Analysis of Algorithms | Set 2 (Worst, Average and Best Cases) | GeeksforGeeks',
#   '37K views',
#   '5 years ago',
#   '/watch?v=rlZpZ8es_6k',
#   'https://i.ytimg.com/vi/rlZpZ8es_6k/hqdefault.jpg'],
#  ['Python | Pandas dataframe.round() | GeeksforGeeks',
#   '4.1K views',
#   '5 years ago',
#   '/watch?v=rOnKa_tzV04',
#   'https://i.ytimg.com/vi/rOnKa_tzV04/hqdefault.jpg'],
#  ['Python | Pandas dataframe.skew() | GeeksforGeeks',
#   '6.8K views',
#   '5 years ago',
#   '/watch?v=wbDxmlpV3t0',
#   'https://i.ytimg.com/vi/rOnKa_tzV04/hqdefault.jpg'],
#  ['Python | Pandas dataframe.subtract() | GeeksforGeeks',
#   '8.3K views',
#   '5 years ago',
#   '/watch?v=yHR-ZUmmrQQ',
#   'https://i.ytimg.com/vi/rOnKa_tzV04/hqdefault.jpg'],
#  ['Python | Pandas dataframe.sub() | GeeksforGeeks',
#   '1K views',
#   '5 years ago',
#   '/watch?v=A3xrtPHMrM8',
#   'https://i.ytimg.com/vi/rOnKa_tzV04/hqdefault.jpg'],
#  ['Python | Pandas dataframe.aggregate() | GeeksforGeeks',
#   '3.1K views',
#   '5 years ago',
#   '/watch?v=RCLtgM2LLhs',
#   'https://i.ytimg.com/vi/rOnKa_tzV04/hqdefault.jpg'],
#  ['Python | Pandas dataframe.add() | GeeksforGeeks',
#   '1.5K views',
#   '5 years ago',
#   '/watch?v=zYmQ3D-HDqY',
#   'https://i.ytimg.com/vi/rOnKa_tzV04/hqdefault.jpg'],
#  ['Geek of the Year 18 in Content Writing- Raj | GeeksforGeeks',
#   '14K views',
#   '5 years ago',
#   '/watch?v=inEhAV6rdxg',
#   'https://i.ytimg.com/vi/rOnKa_tzV04/hqdefault.jpg'],
#  ['Python | Pandas dataframe.sort_index() | GeeksforGeeks',
#   '1.6K views',
#   '5 years ago',
#   '/watch?v=uxPYPnxI9N0',
#   'https://i.ytimg.com/vi/rOnKa_tzV04/hqdefault.jpg'],
#  ...]

# %%
df = pd.DataFrame(data, columns = [ 'title','views','date_time','video_link','thumbnail_link'])

# %%
df.to_csv('Data.csv')

# %%
df.isnull().sum()
# Out:
# title             0
# views             0
# date_time         0
# video_link        0
# thumbnail_link    0
# dtype: int64

# %% [markdown]
# # Youtube Web Scraping | Video Data Scraping

# %%
browser.get('https://www.youtube.com/')
time.sleep(2)

data = []
for link in tqdm(df['video_link']):
    link = 'https://www.youtube.com/' + link
    browser.get(link)

    time.sleep(3)

    soup =  BeautifulSoup(browser.page_source, 'html.parser')

    try:
        title   = soup.find('yt-formatted-string', class_ = 'style-scope ytd-watch-metadata').text
    except:
        title = np.nan
    try:
        views   = soup.find('span', class_ = 'bold style-scope yt-formatted-string').text
    except:
        views = np.nan
    try:
        likes = soup.find('segmented-like-dislike-button-view-model', class_ = 'YtSegmentedLikeDislikeButtonViewModelHost style-scope ytd-menu-renderer').text
    except:
        likes = np.nan
    try:
        description = soup.find('ytd-text-inline-expander','style-scope ytd-watch-metadata').text
    except:
        description = np.nan
        
    data.append([title,views,likes,link,description])
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████| 1888/1888 [3:00:28<00:00,  5.74s/it]

# %%
data
# Out:
# 122

# %%
df = pd.read_csv('Data.csv')
df.head()
# Out:
#    Unnamed: 0                                              title       views  \
# 0           0  Three 90 Challenge | 1.5 Cr Refunded | Geeksfo...   728 views
# 1           1  From Tier 3 College to 20LPA Package 🤑 at Harm...  2.2K views
# 2           2  How I Built an AirBnb Clone from Scratch | MER...  1.1K views
# 3           3  Master Web3 in 2024 (The Ultimate Roadmap) | B...  1.2K views
# 4           4  🚀 Do This to Learn DSA and Get a Job | *Free R...  3.1K views
#
#      date_time            video_link  \
# 0    1 day ago  /watch?v=28wXxweOOFM
# 1   3 days ago  /watch?v=cGPpUdaISGE
# 2   4 days ago  /watch?v=koTBLYNq63I
# 3   7 days ago  /watch?v=CKrM5ouILBg
# 4  11 days ago  /watch?v=VdLUuIeuXqM
#
#                                      thumbnail_link
# 0  https://i.ytimg.com/vi/28wXxweOOFM/hqdefault.jpg
# 1  https://i.ytimg.com/vi/cGPpUdaISGE/hqdefault.jpg
# 2  https://i.ytimg.com/vi/koTBLYNq63I/hqdefault.jpg
# 3  https://i.ytimg.com/vi/CKrM5ouILBg/hqdefault.jpg
# 4  https://i.ytimg.com/vi/VdLUuIeuXqM/hqdefault.jpg

# %%
for link in df['video_link']:
    link = ('https://www.youtube.com/' + link)
    browser.get(link)
    
    break
# Out:
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# Cell In[38], line 3
#       1 for link in df['video_link']:
#       2     link = ('https://www.youtube.com/' + link)
# ----> 3     browser.get(link)
#       5     break
#
# File ~\anaconda3\Lib\site-packages\selenium\webdriver\remote\webdriver.py:363, in WebDriver.get(self, url)
#     361 def get(self, url: str) -> None:
#     362     """Loads a web page in the current browser session."""
# --> 363     self.execute(Command.GET, {"url": url})
#
# File ~\anaconda3\Lib\site-packages\selenium\webdriver\remote\webdriver.py:354, in WebDriver.execute(self, driver_command, params)
#     352 response = self.command_executor.execute(driver_command, params)
#     353 if response:
# --> 354     self.error_handler.check_response(response)
#     355     response["value"] = self._unwrap_value(response.get("value", None))
#     356     return response
#
# File ~\anaconda3\Lib\site-packages\selenium\webdriver\remote\errorhandler.py:229, in ErrorHandler.check_response(self, response)
#     227         alert_text = value["alert"].get("text")
#     228     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 229 raise exception_class(message, screen, stacktrace)
#
# WebDriverException: Message: disconnected: not connected to DevTools
#   (failed to check if window was closed: disconnected: not connected to DevTools)
#   (Session info: chrome=128.0.6613.138)
# Stacktrace:
# 	GetHandleVerifier [0x00007FF6FB269412+29090]
# 	(No symbol) [0x00007FF6FB1DE239]
# 	(No symbol) [0x00007FF6FB09B1DA]
# 	(No symbol) [0x00007FF6FB0828FC]
# 	(No symbol) [0x00007FF6FB0827C0]
# 	(No symbol) [0x00007FF6FB09DAC1]
# 	(No symbol) [0x00007FF6FB135ED9]
# 	(No symbol) [0x00007FF6FB116493]
# 	(No symbol) [0x00007FF6FB0E09D1]
# 	(No symbol) [0x00007FF6FB0E1B31]
# 	GetHandleVerifier [0x00007FF6FB58871D+3302573]
# 	GetHandleVerifier [0x00007FF6FB5D4243+3612627]
# 	GetHandleVerifier [0x00007FF6FB5CA417+3572135]
# 	GetHandleVerifier [0x00007FF6FB325EB6+801862]
# 	(No symbol) [0x00007FF6FB1E945F]
# 	(No symbol) [0x00007FF6FB1E4FB4]
# 	(No symbol) [0x00007FF6FB1E5140]
# 	(No symbol) [0x00007FF6FB1D461F]
# 	BaseThreadInitThunk [0x00007FFC94BA257D+29]
# 	RtlUserThreadStart [0x00007FFC9524AF28+40]

# %%
soup = BeautifulSoup(browser.page_source,'html.parser')
views = soup.find('span','bold style-scope yt-formatted-string').text
# Out:
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 soup = BeautifulSoup(browser.page_source,'html.parser')
#       2 views = soup.find('span','bold style-scope yt-formatted-string').text
#
# File ~\anaconda3\Lib\site-packages\selenium\webdriver\remote\webdriver.py:455, in WebDriver.page_source(self)
#     446 @property
#     447 def page_source(self) -> str:
#     448     """Gets the source of the current page.
#     449
#     450     :Usage:
#    (...)
#     453             driver.page_source
#     454     """
# --> 455     return self.execute(Command.GET_PAGE_SOURCE)["value"]
#
# File ~\anaconda3\Lib\site-packages\selenium\webdriver\remote\webdriver.py:354, in WebDriver.execute(self, driver_command, params)
#     352 response = self.command_executor.execute(driver_command, params)
#     353 if response:
# --> 354     self.error_handler.check_response(response)
#     355     response["value"] = self._unwrap_value(response.get("value", None))
#     356     return response
#
# File ~\anaconda3\Lib\site-packages\selenium\webdriver\remote\errorhandler.py:229, in ErrorHandler.check_response(self, response)
#     227         alert_text = value["alert"].get("text")
#     228     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 229 raise exception_class(message, screen, stacktrace)
#
# WebDriverException: Message: disconnected: not connected to DevTools
#   (failed to check if window was closed: disconnected: not connected to DevTools)
#   (Session info: chrome=128.0.6613.138)
# Stacktrace:
# 	GetHandleVerifier [0x00007FF6FB269412+29090]
# 	(No symbol) [0x00007FF6FB1DE239]
# 	(No symbol) [0x00007FF6FB09B1DA]
# 	(No symbol) [0x00007FF6FB0828FC]
# 	(No symbol) [0x00007FF6FB0827C0]
# 	(No symbol) [0x00007FF6FB09DAC1]
# 	(No symbol) [0x00007FF6FB135ED9]
# 	(No symbol) [0x00007FF6FB116493]
# 	(No symbol) [0x00007FF6FB0E09D1]
# 	(No symbol) [0x00007FF6FB0E1B31]
# 	GetHandleVerifier [0x00007FF6FB58871D+3302573]
# 	GetHandleVerifier [0x00007FF6FB5D4243+3612627]
# 	GetHandleVerifier [0x00007FF6FB5CA417+3572135]
# 	GetHandleVerifier [0x00007FF6FB325EB6+801862]
# 	(No symbol) [0x00007FF6FB1E945F]
# 	(No symbol) [0x00007FF6FB1E4FB4]
# 	(No symbol) [0x00007FF6FB1E5140]
# 	(No symbol) [0x00007FF6FB1D461F]
# 	BaseThreadInitThunk [0x00007FFC94BA257D+29]
# 	RtlUserThreadStart [0x00007FFC9524AF28+40]

# %%
views
# Out:
# '728 views'

# %%
df = pd.DataFrame(data,columns = ['title','views','likes','link','description'])

# %%
df
# Out:
#                                                  title       views likes  \
# 0    Three 90 Challenge | 1.5 Cr Refunded | Geeksfo...   728 views    13
# 1    From Tier 3 College to 20LPA Package 🤑 at Harm...  2.2K views   139
# 2    How I Built an AirBnb Clone from Scratch | MER...  1.1K views    39
# 3    Master Web3 in 2024 (The Ultimate Roadmap) | B...  1.2K views    62
# 4    🚀 Do This to Learn DSA and Get a Job | *Free R...  3.1K views   214
# ..                                                 ...         ...   ...
# 117  Kyun Hai Rohan #successsepareshan? | GeeksforG...  275K views    62
# 118  TREE DATA STRUCTURES | What is Tree? | DSA Cou...  6.8K views    90
# 119  Three 90 Challenge Extended | 100+ Refunds Pro...   33K views    35
# 120  TYPESCRIPT vs JAVASCRIPT | Which one to Choose...  1.1K views    29
# 121  Python's Map Function Explained with Examples ...    1K views    31
#
#                                              link  \
# 0    https://www.youtube.com//watch?v=28wXxweOOFM
# 1    https://www.youtube.com//watch?v=cGPpUdaISGE
# 2    https://www.youtube.com//watch?v=koTBLYNq63I
# 3    https://www.youtube.com//watch?v=CKrM5ouILBg
# 4    https://www.youtube.com//watch?v=VdLUuIeuXqM
# ..                                            ...
# 117  https://www.youtube.com//watch?v=v41P3Y5Xol8
# 118  https://www.youtube.com//watch?v=AylOfzYJ2qE
# 119  https://www.youtube.com//watch?v=FVCERWiQSDY
# 120  https://www.youtube.com//watch?v=BFf8n2RrKtM
# 121  https://www.youtube.com//watch?v=L66_EOxzLKI
#
#                                            description
# 0    Three 90 Challenge : ENDING SOON \nREGISTER NO...
# 1    "From a Tier 3 college to a 20 LPA package as ...
# 2    In this video, we dive into building a fully f...
# 3    Unlock the future of the digital economy with ...
# 4    🚀 Do This to Learn DSA and Get a Job | Free Re...
# ..                                                 ...
# 117  Kya aapko bhi chaiye aise pareshani?\nToh Roha...
# 118  Welcome to the next video of our DSA Course, w...
# 119  Start the Three 90 Challenge Today: https://bi...
# 120  Let us dive into the comparison between TypeSc...
# 121  In this Python tutorial, we're exploring the s...
#
# [122 rows x 5 columns]

# %%
df = df.dropna()

# %%
df.to_csv('GFG.csv')
